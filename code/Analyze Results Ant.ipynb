# %%
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd

import matplotlib.patches as mpatches
from matplotlib.lines import Line2D

# %% [markdown]
# # Ant Results

# %%
ant_cpo_0 = pd.read_csv('./results/ant/cpo_0.csv')
ant_cpo_1 = pd.read_csv('./results/ant/cpo_1.csv')
ant_cpo_2 = pd.read_csv('./results/ant/cpo_2.csv')
ant_cpo_3 = pd.read_csv('./results/ant/cpo_3.csv')
ant_cpo_4 = pd.read_csv('./results/ant/cpo_4.csv')
ant_cpo_5 = pd.read_csv('./results/ant/cpo_5.csv')
ant_cpo_6 = pd.read_csv('./results/ant/cpo_6.csv')
ant_cpo_7 = pd.read_csv('./results/ant/cpo_7.csv')
ant_cpo_8 = pd.read_csv('./results/ant/cpo_8.csv')
ant_cpo_9 = pd.read_csv('./results/ant/cpo_9.csv')

cpo_list = [ant_cpo_0, ant_cpo_1, ant_cpo_2, ant_cpo_3, ant_cpo_4, ant_cpo_5, ant_cpo_6, ant_cpo_7, ant_cpo_8, ant_cpo_9]

ant_cpo_rewards = [results['Metrics/EpRet'] for results in cpo_list]
ant_cpo_costs = [results['Metrics/EpCost'] for results in cpo_list]

ant_cpo_mean_rewards = np.mean(ant_cpo_rewards, axis=0)
ant_cpo_mean_costs = np.mean(ant_cpo_costs, axis=0)

ant_cpo_std_rewards = np.std(ant_cpo_rewards, axis=0)
ant_cpo_std_costs = np.std(ant_cpo_costs, axis=0)

# %%
ant_ppo_0 = pd.read_csv('./results/ant/ppo_0.csv')
ant_ppo_1 = pd.read_csv('./results/ant/ppo_1.csv')
ant_ppo_2 = pd.read_csv('./results/ant/ppo_2.csv')
ant_ppo_3 = pd.read_csv('./results/ant/ppo_3.csv')
ant_ppo_4 = pd.read_csv('./results/ant/ppo_4.csv')
ant_ppo_5 = pd.read_csv('./results/ant/ppo_5.csv')
ant_ppo_6 = pd.read_csv('./results/ant/ppo_6.csv')
ant_ppo_7 = pd.read_csv('./results/ant/ppo_7.csv')
ant_ppo_8 = pd.read_csv('./results/ant/ppo_8.csv')
ant_ppo_9 = pd.read_csv('./results/ant/ppo_9.csv')

ppo_list = [ant_ppo_0, ant_ppo_1, ant_ppo_2, ant_ppo_3, ant_ppo_4, ant_ppo_5, ant_ppo_6, ant_ppo_7, ant_ppo_8, ant_ppo_9]

ant_ppo_rewards = [results['Metrics/EpRet'] for results in ppo_list]
ant_ppo_costs = [results['Metrics/EpCost'] for results in ppo_list]

ant_ppo_mean_rewards = np.mean(ant_ppo_rewards, axis=0)
ant_ppo_mean_costs = np.mean(ant_ppo_costs, axis=0)

ant_ppo_std_rewards = np.std(ant_ppo_rewards, axis=0)
ant_ppo_std_costs = np.std(ant_ppo_costs, axis=0)

# %%
ant_ppolag_0 = pd.read_csv('./results/ant/ppo_lag_0.csv')
ant_ppolag_1 = pd.read_csv('./results/ant/ppo_lag_1.csv')
ant_ppolag_2 = pd.read_csv('./results/ant/ppo_lag_2.csv')
ant_ppolag_3 = pd.read_csv('./results/ant/ppo_lag_3.csv')
ant_ppolag_4 = pd.read_csv('./results/ant/ppo_lag_4.csv')
ant_ppolag_5 = pd.read_csv('./results/ant/ppo_lag_5.csv')
ant_ppolag_6 = pd.read_csv('./results/ant/ppo_lag_6.csv')
ant_ppolag_7 = pd.read_csv('./results/ant/ppo_lag_7.csv')
ant_ppolag_8 = pd.read_csv('./results/ant/ppo_lag_8.csv')
ant_ppolag_9 = pd.read_csv('./results/ant/ppo_lag_9.csv')

ppolag_list = [ant_ppolag_0, ant_ppolag_1, ant_ppolag_2, ant_ppolag_3, ant_ppolag_4, ant_ppolag_5, ant_ppolag_6, ant_ppolag_7, ant_ppolag_8, ant_ppolag_9]

ant_ppolag_rewards = [results['Metrics/EpRet'] for results in ppolag_list]
ant_ppolag_costs = [results['Metrics/EpCost'] for results in ppolag_list]

ant_ppolag_mean_rewards = np.mean(ant_ppolag_rewards, axis=0)
ant_ppolag_mean_costs = np.mean(ant_ppolag_costs, axis=0)

ant_ppolag_std_rewards = np.std(ant_ppolag_rewards, axis=0)
ant_ppolag_std_costs = np.std(ant_ppolag_costs, axis=0)

# %%
ant_cppo_pid_0 = pd.read_csv('./results/ant/cppo_0.csv')
ant_cppo_pid_1 = pd.read_csv('./results/ant/cppo_1.csv')
ant_cppo_pid_2 = pd.read_csv('./results/ant/cppo_2.csv')
ant_cppo_pid_3 = pd.read_csv('./results/ant/cppo_3.csv')
ant_cppo_pid_4 = pd.read_csv('./results/ant/cppo_4.csv')
ant_cppo_pid_5 = pd.read_csv('./results/ant/cppo_5.csv')
ant_cppo_pid_6 = pd.read_csv('./results/ant/cppo_6.csv')
ant_cppo_pid_7 = pd.read_csv('./results/ant/cppo_7.csv')
ant_cppo_pid_8 = pd.read_csv('./results/ant/cppo_8.csv')
ant_cppo_pid_9 = pd.read_csv('./results/ant/cppo_9.csv')

cppo_pid_list = [ant_cppo_pid_0, ant_cppo_pid_1, ant_cppo_pid_2, ant_cppo_pid_3, ant_cppo_pid_4, ant_cppo_pid_5, ant_cppo_pid_6, ant_cppo_pid_7, ant_cppo_pid_8, ant_cppo_pid_9]

ant_cppo_pid_rewards = [results['Metrics/EpRet'] for results in cppo_pid_list]
ant_cppo_pid_costs = [results['Metrics/EpCost'] for results in cppo_pid_list]

ant_cppo_pid_mean_rewards = np.mean(ant_cppo_pid_rewards, axis=0)
ant_cppo_pid_mean_costs = np.mean(ant_cppo_pid_costs, axis=0)

ant_cppo_pid_std_rewards = np.std(ant_cppo_pid_rewards, axis=0)
ant_cppo_pid_std_costs = np.std(ant_cppo_pid_costs, axis=0)

# %%
ant_clear_0 = pd.read_csv('./results/ant/clear_0.csv')
ant_clear_1 = pd.read_csv('./results/ant/clear_1.csv')
ant_clear_2 = pd.read_csv('./results/ant/clear_2.csv')
ant_clear_3 = pd.read_csv('./results/ant/clear_3.csv')
ant_clear_4 = pd.read_csv('./results/ant/clear_4.csv')
ant_clear_5 = pd.read_csv('./results/ant/clear_5.csv')
# ant_clear_6 = pd.read_csv('./results/ant/clear_6.csv')
ant_clear_7 = pd.read_csv('./results/ant/clear_7.csv')
ant_clear_8 = pd.read_csv('./results/ant/clear_8.csv')
ant_clear_9 = pd.read_csv('./results/ant/clear_9.csv')

clear_list = [ant_clear_0, ant_clear_1, ant_clear_2, ant_clear_3, ant_clear_4, ant_clear_5, ant_clear_7, ant_clear_8, ant_clear_9] 

ant_clear_rewards = [results['Metrics/EpRet'] for results in clear_list]
ant_clear_costs = [results['Metrics/EpCost'] for results in clear_list]

ant_clear_mean_rewards = np.mean(ant_clear_rewards, axis=0)
ant_clear_mean_costs = np.mean(ant_clear_costs, axis=0)

ant_clear_std_rewards = np.std(ant_clear_rewards, axis=0)
ant_clear_std_costs = np.std(ant_clear_costs, axis=0)

# %%
def aggregate_metrics(results_list, task_sequence, task_length):
    nominal_costs, back_costs, front_costs = [], [], []
    nominal_forgets, back_forgets, front_forgets = [], [], []
    nominal_rew_forgets, back_rew_forgets, front_rew_forgets = [], [], []
    nominal_rewards, back_rewards, front_rewards = [], [], []
    for result in results_list:
        nominal_cost, back_cost, front_cost, nominal_forget, back_forget, front_forget, nominal_rew, back_rew, front_rew, nominal_rew_forget, back_rew_forget, front_rew_forget = calculate_metrics(result, task_sequence, task_length)
        nominal_costs.append(nominal_cost)
        back_costs.append(back_cost)
        front_costs.append(front_cost)
        nominal_forgets.append(nominal_forget)
        back_forgets.append(back_forget) 
        front_forgets.append(front_forget)
        nominal_rewards.append(nominal_rew)
        back_rewards.append(back_rew)
        front_rewards.append(front_rew)
        nominal_rew_forgets.append(nominal_rew_forget)
        front_rew_forgets.append(front_rew_forget)
        back_rew_forgets.append(back_rew_forget)

    print("COSTS:")
    print(f'Nominal total costs: {np.mean(nominal_costs)} +/- {np.std(nominal_costs)}')
    print(f'Back total costs: {np.mean(back_costs)} +/- {np.std(back_costs)}')
    print(f'Front total costs: {np.mean(front_costs)} +/- {np.std(front_costs)}')
    print(f'Overall costs: {np.mean([np.mean(nominal_costs), np.mean(back_costs), np.mean(front_costs)])} ' 
          f'+/- {np.mean([np.std(nominal_costs), np.std(back_costs), np.std(front_costs)])}')

    print("FORGETTING RATIO:")
    print(f'Nominal forgetting: {np.mean(nominal_forgets)} +/- {np.std(nominal_forgets)}')
    print(f'Back forgetting: {np.mean(back_forgets)} +/- {np.std(back_forgets)}')
    print(f'Front forgetting: {np.mean(front_forgets)} +/- {np.std(front_forgets)}')
    print(f'Overall forgetting: {np.mean([np.mean(nominal_forgets), np.mean(back_forgets), np.mean(front_forgets)])} ' 
          f'+/- {np.mean([np.std(nominal_forgets), np.std(back_forgets), np.std(front_forgets)])}')
    
    print("REWARD FORGETTING:")
    print(f'Nominal forgetting: {np.mean(nominal_rew_forgets)} +/- {np.std(nominal_rew_forgets)}')
    print(f'Back forgetting: {np.mean(back_rew_forgets)} +/- {np.std(back_rew_forgets)}')
    print(f'Front forgetting: {np.mean(front_rew_forgets)} +/- {np.std(front_rew_forgets)}')
    print(f'Overall forgetting: {np.mean([np.mean(nominal_rew_forgets), np.mean(back_rew_forgets), np.mean(front_rew_forgets)])} ' 
          f'+/- {np.mean([np.std(nominal_rew_forgets), np.std(back_rew_forgets), np.std(front_rew_forgets)])}')
    
    initial = [r['Metrics/EpRet'][0] for r in results_list]
    possible_forgetting = np.mean([np.mean(nominal_rewards), np.mean(back_rewards), np.mean(front_rewards)]) - np.mean(initial)
    print(np.mean(initial), possible_forgetting)
    norm_forget = np.mean([np.mean(nominal_rew_forgets), np.mean(back_rew_forgets), np.mean(front_rew_forgets)]) / possible_forgetting
    print('NORMALIZED FORGETTING:')
    print(norm_forget)

    print("REWARDS:")
    print(f'Nominal rewards: {np.mean(nominal_rewards)} +/- {np.std(nominal_rewards)}')
    print(f'Back rewards: {np.mean(back_rewards)} +/- {np.std(back_rewards)}')
    print(f'Front rewards: {np.mean(front_rewards)} +/- {np.std(front_rewards)}')
    print(f'Overall rewards: {np.mean([np.mean(nominal_rewards), np.mean(back_rewards), np.mean(front_rewards)])} ' 
          f'+/- {np.mean([np.std(nominal_rewards), np.std(back_rewards), np.std(front_rewards)])}')

def calculate_metrics(results, task_sequence, task_length):
    results = add_task_names(results, task_sequence, task_length)
    nominal_cost, back_cost, front_cost = all_average_total_costs(results, task_length)
    nominal_forget, back_forget, front_forget, nominal_rew_forget, back_rew_forget, front_rew_forget = all_forgetting(results, task_length)
    nominal_rew, back_rew, front_rew = all_rewards(results, task_length)
    return nominal_cost, back_cost, front_cost, nominal_forget, back_forget, front_forget, nominal_rew, back_rew, front_rew, nominal_rew_forget, back_rew_forget, front_rew_forget

def add_task_names(results, task_sequence, task_length):
    task_names = [[task] * task_length for task in task_sequence]
    task_names = np.concatenate(task_names)
    results['task'] = task_names

    return results

def all_average_total_costs(results, task_length):
    nominal_cost = average_total_costs(results, 'nominal', task_length)
    back_cost = average_total_costs(results, 'back', task_length)
    front_cost = average_total_costs(results, 'front', task_length)

    return nominal_cost, back_cost, front_cost

def average_total_costs(results, task_name, task_length):
    task_results = results[results['task'] == task_name]
    task_costs = task_results['Metrics/EpCost'].to_numpy()

    num_visited = int(len(task_costs) / task_length)

    total_costs = []
    for i in range(num_visited):
        task_idx = np.arange(0, task_length) + i * task_length
        total_costs.append(task_costs[task_idx].sum())

    return np.mean(total_costs)

def all_forgetting(results, task_length):
    nominal_forget, nominal_rew_forget = forgetting(results, 'nominal', task_length)
    back_forget, back_rew_forget = forgetting(results, 'back', task_length)
    front_forget, front_rew_forget = forgetting(results, 'front', task_length)

    return nominal_forget, back_forget, front_forget, nominal_rew_forget, back_rew_forget, front_rew_forget

def forgetting(results, task_name, task_length):
    task_results = results[results['task'] == task_name]
    task_rewards = task_results['Metrics/EpRet'].to_numpy()

    endpoint = task_length - 1
    startpoint = task_length + 1 # to purge the buffer

    num_visited = int(len(task_rewards) / task_length)
    num_restart = num_visited - 1

    forget_values = []
    abs_forget = []
    for i in range(num_restart):
        A = task_rewards[endpoint * (i+1)]
        B = task_rewards[startpoint * (i+1)]
        forget = (A - B) / (np.abs(A)) * 100

        forget_values.append(forget)
        abs_forget.append(A-B)
    
    return np.mean(forget_values), np.mean(abs_forget)

def all_rewards(results, task_length):
    nominal_rew = rewards(results, 'nominal', task_length)
    back_rew = rewards(results, 'back', task_length)
    front_rew = rewards(results, 'front', task_length)

    return nominal_rew, back_rew, front_rew

def rewards(results, task_name, task_length):
    task_results = results[results['task'] == task_name]
    task_rewards = task_results['Metrics/EpRet'].to_numpy()

    endpoint = task_length - 1

    num_visited = int(len(task_rewards) / task_length)

    reward_vals = []
    for i in range(num_visited):
        rew = task_rewards[endpoint * (i+1)]
        reward_vals.append(rew)
    
    return reward_vals[-1]

# %%
def bootstrap_ci(data, num_samples=10000, ci=95):
    if len(data) == 0:
        return np.nan, np.nan
    bootstrapped_means = np.array([
        np.mean(np.random.choice(data, size=len(data), replace=True))
        for _ in range(num_samples)
    ])
    lower = np.percentile(bootstrapped_means, (100 - ci) / 2)
    upper = np.percentile(bootstrapped_means, 100 - (100 - ci) / 2)
    return lower, upper

def aggregate_metrics_bootstrap(results_list, task_sequence, task_length):
    nominal_costs, back_costs, front_costs = [], [], []
    nominal_forgets, back_forgets, front_forgets = [], [], []
    nominal_rew_forgets, back_rew_forgets, front_rew_forgets = [], [], []
    nominal_rewards, back_rewards, front_rewards = [], [], []

    for result in results_list:
        nominal_cost, back_cost, front_cost, nominal_forget, back_forget, front_forget, nominal_rew, back_rew, front_rew, nominal_rew_forget, back_rew_forget, front_rew_forget = calculate_metrics(result, task_sequence, task_length)
        nominal_costs.append(nominal_cost)
        back_costs.append(back_cost)
        front_costs.append(front_cost)
        nominal_forgets.append(nominal_forget)
        back_forgets.append(back_forget)
        front_forgets.append(front_forget)
        nominal_rewards.append(nominal_rew)
        back_rewards.append(back_rew)
        front_rewards.append(front_rew)
        nominal_rew_forgets.append(nominal_rew_forget)
        front_rew_forgets.append(front_rew_forget)
        back_rew_forgets.append(back_rew_forget)

    def print_metric(title, data_groups, labels):
        print(title)
        all_means = []
        for label, data in zip(labels, data_groups):
            mean = np.mean(data)
            lower, upper = bootstrap_ci(data)
            print(f'{label}: {mean:.3f} [{lower:.3f}, {upper:.3f}]')
            all_means.append(mean)
        overall_mean = np.mean(all_means)
        # Combine all data for bootstrapping overall
        combined = np.concatenate(data_groups)
        lower, upper = bootstrap_ci(combined)
        print(f'Overall: {overall_mean:.3f} [{lower:.3f}, {upper:.3f}]\n')

    print_metric("COSTS:", [nominal_costs, back_costs, front_costs], ["Nominal total costs", "Back total costs", "Front total costs"])
    print_metric("FORGETTING RATIO:", [nominal_forgets, back_forgets, front_forgets], ["Nominal forgetting", "Back forgetting", "Front forgetting"])
    print_metric("REWARD FORGETTING:", [nominal_rew_forgets, back_rew_forgets, front_rew_forgets], ["Nominal forgetting", "Back forgetting", "Front forgetting"])

    # print("NORMALIZED FORGETTING:")
    # initial = [r['Metrics/EpRet'][0] for r in results_list]
    # initial_mean = np.mean(initial)
    # mean_reward = np.mean([np.mean(nominal_rewards), np.mean(back_rewards), np.mean(front_rewards)])
    # possible_forgetting = mean_reward - initial_mean
    # mean_rew_forgetting = np.mean([np.mean(nominal_rew_forgets), np.mean(back_rew_forgets), np.mean(front_rew_forgets)])
    # norm_forget = mean_rew_forgetting / possible_forgetting if possible_forgetting != 0 else np.nan
    # print(f'{norm_forget:.3f} (initial mean: {initial_mean:.3f}, possible forgetting: {possible_forgetting:.3f})\n')


    initial = [r['Metrics/EpRet'][0] for r in results_list]
    mean_reward = np.mean(np.vstack([nominal_rewards, back_rewards, front_rewards]), axis=0)
    possible_forgetting = mean_reward - initial
    actual_forgetting = np.mean(np.vstack([nominal_rew_forgets, back_rew_forgets, front_rew_forgets]), axis=0)
    norm_forget = actual_forgetting / possible_forgetting 
    print_metric("Normalized Forgetting:", [norm_forget], ["Across tasks forgetting"])


    print_metric("REWARDS:", [nominal_rewards, back_rewards, front_rewards], ["Nominal rewards", "Back rewards", "Front rewards"])

# %%
tasks_encountered = ['nominal', 'back', 'nominal', 'front', 'back', 'nominal', 'front', 'nominal']


aggregate_metrics_bootstrap(cpo_list, tasks_encountered, 50)
# Out:
# COSTS:
# Nominal total costs: 838.204 [788.352, 886.307]
# Back total costs: 577.709 [456.892, 700.799]
# Front total costs: 64.050 [18.111, 135.023]
# Overall: 493.321 [369.669, 618.625]
#
# FORGETTING RATIO:
# Nominal forgetting: 44.920 [33.612, 56.816]
# Back forgetting: 113.480 [89.814, 136.372]
# Front forgetting: 94.131 [71.526, 116.428]
# Overall: 84.177 [69.208, 99.455]
#
# REWARD FORGETTING:
# Nominal forgetting: 786.034 [594.022, 993.870]
# Back forgetting: 1738.876 [1359.816, 2115.977]
# Front forgetting: 893.087 [691.375, 1109.153]
# Overall: 1139.332 [930.113, 1369.244]
#
# Normalized Forgetting:
# Across tasks forgetting: 0.522 [0.420, 0.613]
# Overall: 0.522 [0.420, 0.612]
#
# REWARDS:
# Nominal rewards: 2034.464 [1955.403, 2110.021]
# Back rewards: 1584.887 [1484.119, 1679.331]
# Front rewards: 1028.717 [865.231, 1190.806]
# Overall: 1549.356 [1383.621, 1711.430]

# %%
tasks_encountered = ['nominal', 'back', 'nominal', 'front', 'back', 'nominal', 'front', 'nominal']


aggregate_metrics_bootstrap(clear_list, tasks_encountered, 50)
# Out:
# COSTS:
# Nominal total costs: 1324.666 [182.465, 3265.463]
# Back total costs: 32.920 [16.737, 49.671]
# Front total costs: 124.022 [62.587, 201.786]
# Overall: 493.870 [95.332, 1195.219]
#
# FORGETTING RATIO:
# Nominal forgetting: 198.626 [40.378, 497.562]
# Back forgetting: 934.498 [187.676, 2284.742]
# Front forgetting: 61.957 [53.202, 71.538]
# Overall: 398.360 [103.718, 893.249]
#
# REWARD FORGETTING:
# Nominal forgetting: 192.330 [137.969, 264.060]
# Back forgetting: 169.247 [133.095, 211.028]
# Front forgetting: 185.597 [155.827, 216.921]
# Overall: 182.391 [157.144, 211.553]
#
# Normalized Forgetting:
# Across tasks forgetting: 0.159 [0.136, 0.180]
# Overall: 0.159 [0.136, 0.180]
#
# REWARDS:
# Nominal rewards: 841.349 [572.860, 1198.665]
# Back rewards: 231.039 [97.466, 369.864]
# Front rewards: 434.650 [405.741, 462.248]
# Overall: 502.346 [367.335, 667.936]

# %%
aggregate_metrics_bootstrap(ppolag_list, tasks_encountered, 50)
# Out:
# COSTS:
# Nominal total costs: 1640.287 [1359.386, 1964.724]
# Back total costs: 911.059 [556.559, 1265.364]
# Front total costs: 64.077 [12.696, 131.123]
# Overall: 871.807 [603.424, 1150.408]
#
# FORGETTING RATIO:
# Nominal forgetting: 19.916 [10.477, 31.971]
# Back forgetting: 87.432 [66.184, 107.594]
# Front forgetting: 92.105 [45.312, 158.991]
# Overall: 66.484 [44.940, 92.971]
#
# REWARD FORGETTING:
# Nominal forgetting: 308.491 [193.595, 438.682]
# Back forgetting: 986.698 [748.673, 1201.546]
# Front forgetting: 446.125 [296.111, 598.965]
# Overall: 580.438 [443.363, 728.786]
#
# Normalized Forgetting:
# Across tasks forgetting: 0.267 [0.207, 0.339]
# Overall: 0.267 [0.207, 0.341]
#
# REWARDS:
# Nominal rewards: 2371.560 [2199.340, 2530.057]
# Back rewards: 1351.477 [1126.847, 1554.626]
# Front rewards: 1002.167 [818.033, 1174.404]
# Overall: 1575.068 [1341.710, 1808.923]

# %%
aggregate_metrics_bootstrap(ppo_list, tasks_encountered, 50)
# Out:
# COSTS:
# Nominal total costs: 18362.582 [13347.604, 22951.625]
# Back total costs: 1170.744 [714.903, 1607.427]
# Front total costs: 1176.472 [788.123, 1632.401]
# Overall: 6903.266 [3783.543, 10420.129]
#
# FORGETTING RATIO:
# Nominal forgetting: 19.327 [13.066, 26.260]
# Back forgetting: 84.678 [57.957, 111.287]
# Front forgetting: 27.652 [19.305, 36.623]
# Overall: 43.886 [30.846, 59.036]
#
# REWARD FORGETTING:
# Nominal forgetting: 513.004 [357.351, 684.600]
# Back forgetting: 1073.172 [708.901, 1463.146]
# Front forgetting: 261.646 [171.103, 363.739]
# Overall: 615.941 [445.912, 813.484]
#
# Normalized Forgetting:
# Across tasks forgetting: 0.235 [0.180, 0.300]
# Overall: 0.235 [0.179, 0.301]
#
# REWARDS:
# Nominal rewards: 3605.577 [3066.618, 4051.586]
# Back rewards: 1256.801 [795.500, 1622.742]
# Front rewards: 1243.478 [1082.882, 1387.720]
# Overall: 2035.285 [1596.267, 2503.309]

# %%
aggregate_metrics_bootstrap(cppo_pid_list, tasks_encountered, 50)
# Out:
# COSTS:
# Nominal total costs: 1014.986 [894.840, 1184.361]
# Back total costs: 585.470 [388.313, 770.544]
# Front total costs: 65.770 [12.283, 143.353]
# Overall: 555.409 [391.344, 723.462]
#
# FORGETTING RATIO:
# Nominal forgetting: 21.182 [9.764, 35.730]
# Back forgetting: 82.631 [56.513, 107.481]
# Front forgetting: 67.029 [41.955, 93.411]
# Overall: 56.947 [41.364, 73.371]
#
# REWARD FORGETTING:
# Nominal forgetting: 320.827 [175.525, 498.635]
# Back forgetting: 854.689 [613.443, 1081.105]
# Front forgetting: 461.881 [294.261, 650.842]
# Overall: 545.799 [412.730, 685.923]
#
# Normalized Forgetting:
# Across tasks forgetting: 0.263 [0.190, 0.348]
# Overall: 0.263 [0.190, 0.348]
#
# REWARDS:
# Nominal rewards: 2296.535 [2127.659, 2466.692]
# Back rewards: 1240.845 [1029.379, 1433.781]
# Front rewards: 960.624 [798.899, 1112.301]
# Overall: 1499.335 [1270.769, 1731.867]

# %%
ant_ewc_0 = pd.read_csv('./results/ant/ppo_ewc_0.csv')
ant_ewc_1 = pd.read_csv('./results/ant/ppo_ewc_1.csv')
ant_ewc_2 = pd.read_csv('./results/ant/ppo_ewc_2.csv')
ant_ewc_3 = pd.read_csv('./results/ant/ppo_ewc_3.csv')
ant_ewc_4 = pd.read_csv('./results/ant/ppo_ewc_4.csv')
ant_ewc_5 = pd.read_csv('./results/ant/ppo_ewc_5.csv')
ant_ewc_6 = pd.read_csv('./results/ant/ppo_ewc_6.csv')
ant_ewc_7 = pd.read_csv('./results/ant/ppo_ewc_7.csv')
ant_ewc_8 = pd.read_csv('./results/ant/ppo_ewc_8.csv')
ant_ewc_9 = pd.read_csv('./results/ant/ppo_ewc_9.csv')

ewc_list = [ant_ewc_0, ant_ewc_1, ant_ewc_2, ant_ewc_3, ant_ewc_4, ant_ewc_5, ant_ewc_6, ant_ewc_7, ant_ewc_8, ant_ewc_9]

ant_ewc_rewards = [results['Metrics/EpRet'] for results in ewc_list]
ant_ewc_costs = [results['Metrics/EpCost'] for results in ewc_list]

ant_ewc_mean_rewards = np.mean(ant_ewc_rewards, axis=0)
ant_ewc_mean_costs = np.mean(ant_ewc_costs, axis=0)

ant_ewc_std_rewards = np.std(ant_ewc_rewards, axis=0)
ant_ewc_std_costs = np.std(ant_ewc_costs, axis=0)

# %%
aggregate_metrics_bootstrap(ewc_list, tasks_encountered, 50)
# Out:
# COSTS:
# Nominal total costs: 17927.254 [13253.948, 22127.762]
# Back total costs: 1205.767 [729.383, 1762.118]
# Front total costs: 765.352 [355.691, 1274.342]
# Overall: 6632.791 [3574.188, 10066.471]
#
# FORGETTING RATIO:
# Nominal forgetting: 23.492 [10.180, 41.247]
# Back forgetting: 81.100 [52.747, 107.877]
# Front forgetting: 37.682 [31.552, 45.568]
# Overall: 47.425 [34.108, 62.074]
#
# REWARD FORGETTING:
# Nominal forgetting: 480.821 [246.082, 721.509]
# Back forgetting: 778.751 [500.443, 1053.544]
# Front forgetting: 302.641 [237.556, 380.538]
# Overall: 520.738 [385.680, 666.185]
#
# Normalized Forgetting:
# Across tasks forgetting: 0.200 [0.146, 0.250]
# Overall: 0.200 [0.145, 0.249]
#
# REWARDS:
# Nominal rewards: 3565.394 [2955.134, 4078.928]
# Back rewards: 1440.856 [1177.992, 1656.895]
# Front rewards: 1143.594 [1041.650, 1249.989]
# Overall: 2049.948 [1626.213, 2504.851]

# %%
ant_ewc_loss_0 = pd.read_csv('./results/ant/ewc_cost_loss_0.csv')
ant_ewc_loss_1 = pd.read_csv('./results/ant/ewc_cost_loss_1.csv')
ant_ewc_loss_2 = pd.read_csv('./results/ant/ewc_cost_loss_2.csv')
ant_ewc_loss_3 = pd.read_csv('./results/ant/ewc_cost_loss_3.csv')
ant_ewc_loss_4 = pd.read_csv('./results/ant/ewc_cost_loss_4.csv')
ant_ewc_loss_5 = pd.read_csv('./results/ant/ewc_cost_loss_5.csv')
ant_ewc_loss_6 = pd.read_csv('./results/ant/ewc_cost_loss_6.csv')
ant_ewc_loss_7 = pd.read_csv('./results/ant/ewc_cost_loss_7.csv')
ant_ewc_loss_8 = pd.read_csv('./results/ant/ewc_cost_loss_8.csv')
ant_ewc_loss_9 = pd.read_csv('./results/ant/ewc_cost_loss_9.csv')

ewc_loss_list = [ant_ewc_loss_0, ant_ewc_loss_1, ant_ewc_loss_2, ant_ewc_loss_3, ant_ewc_loss_4, ant_ewc_loss_5, ant_ewc_loss_6, ant_ewc_loss_7, ant_ewc_loss_8, ant_ewc_loss_9]

ant_ewc_loss_rewards = [results['Metrics/EpRet'] for results in ewc_loss_list]
ant_ewc_loss_costs = [results['Metrics/EpCost'] for results in ewc_loss_list]

ant_ewc_loss_mean_rewards = np.mean(ant_ewc_loss_rewards, axis=0)
ant_ewc_loss_mean_costs = np.mean(ant_ewc_loss_costs, axis=0)

ant_ewc_loss_std_rewards = np.std(ant_ewc_loss_rewards, axis=0)
ant_ewc_loss_std_costs = np.std(ant_ewc_loss_costs, axis=0)

# %%
aggregate_metrics_bootstrap(ewc_loss_list, tasks_encountered, 50)
# Out:
# COSTS:
# Nominal total costs: 17927.254 [13019.022, 22071.642]
# Back total costs: 1205.767 [734.013, 1763.003]
# Front total costs: 765.352 [360.707, 1286.159]
# Overall: 6632.791 [3530.234, 10005.272]
#
# FORGETTING RATIO:
# Nominal forgetting: 23.492 [10.273, 40.923]
# Back forgetting: 81.100 [53.892, 107.196]
# Front forgetting: 37.682 [31.574, 45.720]
# Overall: 47.425 [34.109, 61.914]
#
# REWARD FORGETTING:
# Nominal forgetting: 480.821 [250.943, 720.615]
# Back forgetting: 778.751 [504.439, 1050.450]
# Front forgetting: 302.641 [238.314, 381.289]
# Overall: 520.738 [384.471, 667.828]
#
# Normalized Forgetting:
# Across tasks forgetting: 0.200 [0.147, 0.250]
# Overall: 0.200 [0.145, 0.251]
#
# REWARDS:
# Nominal rewards: 3565.394 [2969.504, 4082.774]
# Back rewards: 1440.856 [1183.903, 1658.705]
# Front rewards: 1143.594 [1040.978, 1247.921]
# Overall: 2049.948 [1631.019, 2504.659]

# %%
def convert_reward(safe_ewc):
    safe_ewc['Metrics/EpRet'] += 5* safe_ewc['Metrics/EpCost']
    return safe_ewc

# %%
safe_ewc_0 = convert_reward(pd.read_csv('./results/ant/ppo_ewc_cost_0.csv'))
safe_ewc_1 = convert_reward(pd.read_csv('./results/ant/ppo_ewc_cost_1.csv'))
safe_ewc_2 = convert_reward(pd.read_csv('./results/ant/ppo_ewc_cost_2.csv'))
safe_ewc_3 = convert_reward(pd.read_csv('./results/ant/ppo_ewc_cost_3.csv'))
safe_ewc_4 = convert_reward(pd.read_csv('./results/ant/ppo_ewc_cost_4.csv'))
safe_ewc_5 = convert_reward(pd.read_csv('./results/ant/ppo_ewc_cost_5.csv'))
safe_ewc_6 = convert_reward(pd.read_csv('./results/ant/ppo_ewc_cost_6.csv'))
safe_ewc_7 = convert_reward(pd.read_csv('./results/ant/ppo_ewc_cost_7.csv'))
safe_ewc_8 = convert_reward(pd.read_csv('./results/ant/ppo_ewc_cost_8.csv'))
safe_ewc_9 = convert_reward(pd.read_csv('./results/ant/ppo_ewc_cost_9.csv'))

safe_ewc_list = [safe_ewc_0, safe_ewc_1, safe_ewc_2, safe_ewc_3, safe_ewc_4, safe_ewc_5, safe_ewc_6, safe_ewc_7, safe_ewc_8, safe_ewc_9]

safe_ewc_rewards = [results['Metrics/EpRet'] for results in safe_ewc_list]
safe_ewc_costs = [results['Metrics/EpCost'] for results in safe_ewc_list]

safe_ewc_mean_rewards = np.mean(safe_ewc_rewards, axis=0)
safe_ewc_mean_costs = np.mean(safe_ewc_costs, axis=0)

safe_ewc_std_rewards = np.std(safe_ewc_rewards, axis=0)
safe_ewc_std_costs = np.std(safe_ewc_costs, axis=0)

# %%
aggregate_metrics_bootstrap(safe_ewc_list, tasks_encountered, 50)
# Out:
# COSTS:
# Nominal total costs: 479.990 [400.836, 549.669]
# Back total costs: 541.801 [185.342, 971.506]
# Front total costs: 182.316 [5.539, 496.338]
# Overall: 401.369 [236.364, 587.664]
#
# FORGETTING RATIO:
# Nominal forgetting: 24.108 [15.534, 35.895]
# Back forgetting: 78.789 [53.974, 102.391]
# Front forgetting: 28.326 [11.080, 47.346]
# Overall: 43.741 [30.592, 57.543]
#
# REWARD FORGETTING:
# Nominal forgetting: 387.574 [271.999, 511.952]
# Back forgetting: 845.472 [516.137, 1184.978]
# Front forgetting: 176.345 [71.242, 285.778]
# Overall: 469.797 [322.996, 640.247]
#
# Normalized Forgetting:
# Across tasks forgetting: 0.204 [0.163, 0.248]
# Overall: 0.204 [0.163, 0.246]
#
# REWARDS:
# Nominal rewards: 2469.261 [2373.140, 2564.366]
# Back rewards: 1451.965 [1266.025, 1637.475]
# Front rewards: 973.657 [853.349, 1088.141]
# Overall: 1631.628 [1392.690, 1869.666]

# %%
def plot_rewards(algorithms, ymax=None, save=False, name=None, bigger=False):
    if bigger:
        fig, ax = plt.subplots(figsize=(10,3))
    else:
        fig, ax = plt.subplots(figsize=(10,1))

    TASK_CYCLE = ['nominal', 'back', 'nominal', 'front', 'back', 'nominal', 'front']
    algorithm_colors={'PPO+EWC': 'blue', 
                    'CPO': 'purple',
                    'Safe EWC': 'green',
                    'PPO-Lag': 'orange',
                    'CPPO-PID': 'red',
                    'PPO': 'black',
                    'Exp. Replay': 'brown'}
    cycle_colors = {
        'nominal': 'blue',
        'back': 'orange',
        'front': 'red'
    }

    cycle_hatches = {
        'nominal': '',
        'back': 'oo',
        'front': 'xx'
    }

    if 'PPO+EWC' in algorithms:
        plt.plot(ant_cpo_0['Train/TotalSteps'], ant_ewc_mean_rewards, label='PPO+EWC', color='blue')
        plt.fill_between(
            ant_cpo_0['Train/TotalSteps'],
            ant_ewc_mean_rewards - ant_ewc_std_rewards,
            ant_ewc_mean_rewards + ant_ewc_std_rewards,
            color='blue', alpha=0.2
        )

    if 'CPO' in algorithms:
        plt.plot(ant_cpo_0['Train/TotalSteps'], ant_cpo_mean_rewards, label='CPO', color='purple')
        plt.fill_between(
            ant_cpo_0['Train/TotalSteps'],
            ant_cpo_mean_rewards - ant_cpo_std_rewards,
            ant_cpo_mean_rewards + ant_cpo_std_rewards,
            color='purple', alpha=0.2
        )

    if 'Safe EWC' in algorithms:
        plt.plot(ant_cpo_0['Train/TotalSteps'], safe_ewc_mean_rewards, label='Safe EWC', color='green')
        plt.fill_between(
            ant_cpo_0['Train/TotalSteps'],
            safe_ewc_mean_rewards - safe_ewc_std_rewards,
            safe_ewc_mean_rewards + safe_ewc_std_rewards,
            color='green', alpha=0.2
        )

    if 'PPO-Lag' in algorithms:
        plt.plot(ant_ppolag_0['Train/TotalSteps'], ant_ppolag_mean_rewards, label='PPO-Lag', color='orange')
        plt.fill_between(
            ant_ppolag_0['Train/TotalSteps'],
            ant_ppolag_mean_rewards - ant_ppolag_std_rewards,
            ant_ppolag_mean_rewards + ant_ppolag_std_rewards,
            color='orange', alpha=0.2
        )

    if 'CPPO-PID' in algorithms:
        plt.plot(ant_cppo_pid_0['Train/TotalSteps'], ant_cppo_pid_mean_rewards, label='CPPO-PID', color='red', alpha=0.5)
        plt.fill_between(
            ant_cppo_pid_0['Train/TotalSteps'],
            ant_cppo_pid_mean_rewards - ant_cppo_pid_std_rewards,
            ant_cppo_pid_mean_rewards + ant_cppo_pid_std_rewards,
            color='red', alpha=0.2
        )

    if 'PPO' in algorithms:
        plt.plot(ant_ppo_0['Train/TotalSteps'], ant_ppo_mean_rewards, label='PPO', color='black', alpha=0.5)
        plt.fill_between(
            ant_ppo_0['Train/TotalSteps'],
            ant_ppo_mean_rewards - ant_ppo_std_rewards,
            ant_ppo_mean_rewards + ant_ppo_std_rewards,
            color='black', alpha=0.2
        )

    if 'Exp. Replay' in algorithms:
        plt.plot(ant_clear_0['Train/TotalSteps'], ant_clear_mean_rewards, label='Exp. Replay', color='brown', alpha=0.5)
        plt.fill_between(
            ant_clear_0['Train/TotalSteps'],
            ant_clear_mean_rewards - ant_clear_std_rewards,
            ant_clear_mean_rewards + ant_clear_std_rewards,
            color='brown', alpha=0.2
        )

    x_vals = range(0, max(ant_cpo_0['Train/TotalSteps']) + 1, 1000000)
    for i, x in enumerate(x_vals[:-1]):  # Exclude the last x-value as it doesn't define a region
        # Get the current task from the cycle
        task = TASK_CYCLE[i % len(TASK_CYCLE)]
        
        # Shade the region between the current and next x value
        plt.axvline(x=x, color='gray', linestyle='--', linewidth=1)
        plt.fill_between([x, x_vals[i + 1]], ant_ewc_0['Metrics/EpRet'].min(), ant_ewc_0['Metrics/EpRet'].max(), color=cycle_colors[task],  hatch=cycle_hatches[task], alpha=0.1)

    plt.axvline(x=0, color='gray', linestyle='--', linewidth=1, label='Task Change')

    legend_patches = []
    for task in cycle_colors:
        patch = mpatches.Patch(
            facecolor=cycle_colors[task], 
            hatch=cycle_hatches[task], 
            label=task,
            edgecolor='gray',  # Optional: add edgecolor to improve visibility in legend,
            alpha=0.3
        )
        legend_patches.append(patch)

    for algorithm in algorithms:
        custom_line = Line2D([0], [0], color=algorithm_colors[algorithm], lw=2, linestyle='-', label=algorithm.upper())
        legend_patches.append(custom_line)
    # Add legend to the plot, some options commented for generating concise paper figures
    if bigger:
        plt.legend(handles=legend_patches, title='Task/Algorithm', loc='lower center', bbox_to_anchor=(0.5, -0.5), ncol=5, shadow=True, columnspacing=0.6)
    else:
        plt.legend(handles=legend_patches, title='Task/Algorithm', loc='lower center', bbox_to_anchor=(0.5, -1.1), ncol=6, shadow=True, columnspacing=0.6)

    # plt.xlabel("Training Timesteps")
    plt.ylabel("Reward")
    plt.title("Damaged HalfCheetah Velocity")
    if ymax is not None:
        plt.ylim(-670, ymax)

    plt.xlim(0, 8_000_000)
    # from matplotlib.ticker import ScalarFormatter

    # ax.yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
    # ax.ticklabel_format(style='sci', axis='y', scilimits=(0, 0))  # Apply scientific notation to y-axis

    if save:
        plt.savefig(f'./results/plots/{name}.png', bbox_inches='tight')

# %%
algorithms = ['Safe EWC', 'CPO', 'CPPO-PID']
# algorithms = ['Safe EWC', 'CPO']
plot_rewards(algorithms, 2750, True, 'reward_halfant')

# %%
algorithms = ['PPO+EWC', 'CPO', 'Safe EWC', 'PPO-Lag', 'CPPO-PID', 'PPO', 'Exp. Replay']
for algorithm in algorithms:
    plot_rewards([algorithm], 4500, True, f'{algorithm}_halfant_reward', bigger=True)

# %%
plot_rewards(algorithms, 4500, True, f'all_halfant_reward', bigger=True)

# %%
def plot_costs(algorithms, ymax=None, save=False, name=None):
    plt.figure(figsize=(10,3))

    TASK_CYCLE = ['nominal', 'back', 'nominal', 'front', 'back', 'nominal', 'front']
    algorithm_colors={'PPO+EWC': 'blue', 
                    'CPO': 'orange',
                    'Safe EWC': 'green',
                    'PPO-Lag': 'purple',
                    'CPPO-PID': 'red',
                    'PPO': 'black',
                    'Exp. Replay': 'brown'}
    cycle_colors = {
        'nominal': 'blue',
        'back': 'orange',
        'front': 'red'
    }

    cycle_hatches = {
        'nominal': '',
        'back': 'oo',
        'front': 'xx'
    }

    if 'PPO+EWC' in algorithms:
        plt.plot(ant_cpo_0['Train/TotalSteps'], ant_ewc_mean_costs, label='PPO+EWC', color='blue')
        plt.fill_between(
            ant_cpo_0['Train/TotalSteps'],
            ant_ewc_mean_costs - ant_ewc_std_costs,
            ant_ewc_mean_costs + ant_ewc_std_costs,
            color='blue', alpha=0.2
        )

    if 'CPO' in algorithms:
        plt.plot(ant_cpo_0['Train/TotalSteps'], ant_cpo_mean_costs, label='CPO', color='orange')
        plt.fill_between(
            ant_cpo_0['Train/TotalSteps'],
            ant_cpo_mean_costs - ant_cpo_std_costs,
            ant_cpo_mean_costs + ant_cpo_std_costs,
            color='orange', alpha=0.2
        )

    if 'Safe EWC' in algorithms:
        plt.plot(ant_cpo_0['Train/TotalSteps'], safe_ewc_mean_costs, label='Safe EWC', color='green')
        plt.fill_between(
            ant_cpo_0['Train/TotalSteps'],
            safe_ewc_mean_costs - safe_ewc_std_costs,
            safe_ewc_mean_costs + safe_ewc_std_costs,
            color='green', alpha=0.2
        )

    if 'PPO-Lag' in algorithms:
        plt.plot(ant_ppolag_0['Train/TotalSteps'], ant_ppolag_mean_costs, label='PPO-Lag', color='purple')
        plt.fill_between(
            ant_ppolag_0['Train/TotalSteps'],
            ant_ppolag_mean_costs - ant_ppolag_std_costs,
            ant_ppolag_mean_costs + ant_ppolag_std_costs,
            color='purple', alpha=0.2
        )

    if 'CPPO-PID' in algorithms:
        plt.plot(ant_cppo_pid_0['Train/TotalSteps'], ant_cppo_pid_mean_costs, label='CPPO-PID', color='red', alpha=0.5)
        plt.fill_between(
            ant_cppo_pid_0['Train/TotalSteps'],
            ant_cppo_pid_mean_costs - ant_cppo_pid_std_costs,
            ant_cppo_pid_mean_costs + ant_cppo_pid_std_costs,
            color='red', alpha=0.2
        )

    if 'PPO' in algorithms:
        plt.plot(ant_ppo_0['Train/TotalSteps'], ant_ppo_mean_costs, label='PPO', color='black', alpha=0.5)
        plt.fill_between(
            ant_ppo_0['Train/TotalSteps'],
            ant_ppo_mean_costs - ant_ppo_std_costs,
            ant_ppo_mean_costs + ant_ppo_std_costs,
            color='black', alpha=0.2
        )

    if 'Exp. Replay' in algorithms:
        plt.plot(ant_clear_0['Train/TotalSteps'], ant_clear_mean_costs, label='Exp. Replay', color='brown', alpha=0.5)
        plt.fill_between(
            ant_clear_0['Train/TotalSteps'],
            ant_clear_mean_costs - ant_clear_std_costs,
            ant_clear_mean_costs + ant_clear_std_costs,
            color='brown', alpha=0.2
        )

    x_vals = range(0, max(ant_cpo_0['Train/TotalSteps']) + 1, 1000000)
    for i, x in enumerate(x_vals[:-1]):  # Exclude the last x-value as it doesn't define a region
        # Get the current task from the cycle
        task = TASK_CYCLE[i % len(TASK_CYCLE)]
        
        # Shade the region between the current and next x value
        plt.axvline(x=x, color='gray', linestyle='--', linewidth=1)
        plt.fill_between([x, x_vals[i + 1]], ant_ewc_0['Metrics/EpCost'].min(), ant_ewc_0['Metrics/EpCost'].max(), color=cycle_colors[task],  hatch=cycle_hatches[task], alpha=0.1)

    plt.axvline(x=0, color='gray', linestyle='--', linewidth=1, label='Task Change')

    legend_patches = []
    for task in cycle_colors:
        patch = mpatches.Patch(
            facecolor=cycle_colors[task], 
            hatch=cycle_hatches[task], 
            label=task,
            edgecolor='gray',  # Optional: add edgecolor to improve visibility in legend,
            alpha=0.3
        )
        legend_patches.append(patch)

    for algorithm in algorithms:
        custom_line = Line2D([0], [0], color=algorithm_colors[algorithm], lw=2, linestyle='--', label=algorithm.upper())
        legend_patches.append(custom_line)
    # Add legend to the plot
    plt.legend(handles=legend_patches, title='Task/Algorithm', loc='lower center', bbox_to_anchor=(0.5, -0.55), ncol=5, shadow=True, columnspacing=0.6)


    plt.xlabel("Training Timesteps")
    plt.ylabel("Cost")
    plt.title("Damaged HalfCheetah Velocity")
    if ymax is not None:
        plt.ylim(0.5, ymax)
    plt.yscale('log')

    if save:
        plt.savefig(f'./results/plots/{name}.png', bbox_inches='tight')

# %%
plot_costs(algorithms, 1000, True, 'all_halfant_cost')

# %%
algorithms = ['PPO+EWC', 'CPO', 'Safe EWC', 'PPO-Lag', 'CPPO-PID', 'PPO', 'Exp. Replay']
for algorithm in algorithms:
    plot_costs([algorithm], 1000, True, f'{algorithm}_halfant_cost')

# %% [markdown]
# ## Statistical Analysis

# %%
from scipy.stats import mannwhitneyu
from scipy.stats import PermutationMethod
import seaborn as sns

def get_metrics(results_list, task_sequence, task_length):
    nominal_costs, back_costs, front_costs = [], [], []
    nominal_forgets, back_forgets, front_forgets = [], [], []
    nominal_rew_forgets, back_rew_forgets, front_rew_forgets = [], [], []
    nominal_rewards, back_rewards, front_rewards = [], [], []

    for result in results_list:
        nominal_cost, back_cost, front_cost, nominal_forget, back_forget, front_forget, nominal_rew, back_rew, front_rew, nominal_rew_forget, back_rew_forget, front_rew_forget = calculate_metrics(result, task_sequence, task_length)
        nominal_costs.append(nominal_cost)
        back_costs.append(back_cost)
        front_costs.append(front_cost)
        nominal_forgets.append(nominal_forget)
        back_forgets.append(back_forget)
        front_forgets.append(front_forget)
        nominal_rewards.append(nominal_rew)
        back_rewards.append(back_rew)
        front_rewards.append(front_rew)
        nominal_rew_forgets.append(nominal_rew_forget)
        front_rew_forgets.append(front_rew_forget)
        back_rew_forgets.append(back_rew_forget)

    initial = [r['Metrics/EpRet'][0] for r in results_list]
    mean_reward = np.mean(np.vstack([nominal_rewards, back_rewards, front_rewards]), axis=0)
    possible_forgetting = mean_reward - initial
    actual_forgetting = np.mean(np.vstack([nominal_rew_forgets, back_rew_forgets, front_rew_forgets]), axis=0)
    norm_forget = actual_forgetting / possible_forgetting 

    rewards = np.vstack([nominal_rewards, front_rewards, back_rewards]).mean(axis=0)
    costs = np.vstack([nominal_costs, front_costs, back_costs]).mean(axis=0)
    exact_forgets = np.vstack([nominal_forgets, front_forgets, back_forgets]).mean(axis=0)

    return rewards, norm_forget, costs, exact_forgets

def get_all_metrics():
    ppo_rew, ppo_forget, ppo_cost, ppo_raw_forget = get_metrics(ppo_list, tasks_encountered, 50)
    cpo_rew, cpo_forget, cpo_cost, cpo_raw_forget = get_metrics(cpo_list, tasks_encountered, 50)
    cppo_pid_rew, cppo_pid_forget, cppo_pid_cost, cppo_pid_raw_forget = get_metrics(cppo_pid_list, tasks_encountered, 50)
    ppo_lag_rew, ppo_lag_forget, ppo_lag_cost, ppo_lag_raw_forget = get_metrics(ppolag_list, tasks_encountered, 50)
    ewc_rew, ewc_forget, ewc_cost, ewc_raw_forget = get_metrics(ewc_list, tasks_encountered, 50)
    clear_rew, clear_forget, clear_cost, clear_raw_forget = get_metrics(clear_list, tasks_encountered, 50)
    safe_ewc_rew, safe_ewc_forget, safe_ewc_cost, safe_ewc_raw_forget = get_metrics(safe_ewc_list, tasks_encountered, 50)

    print('Rewards')
    rews = [ppo_rew, cpo_rew, cppo_pid_rew, ppo_lag_rew, ewc_rew, clear_rew, safe_ewc_rew]
    test_metric(rews, 'Rewards')
    print('')

    print('Normalized Forgetting')
    forgets = [ppo_forget, cpo_forget, cppo_pid_forget, ppo_lag_forget, ewc_forget, clear_forget, safe_ewc_forget]
    test_metric(forgets, 'Normalized Forgetting')
    print('')

    print('Costs')
    costs = [ppo_cost, cpo_cost, cppo_pid_cost, ppo_lag_cost, ewc_cost, clear_cost, safe_ewc_cost]
    test_metric(costs, 'Costs')
    print('')

def test_metric(values, metric_name):
    alg_list = ['PPO', 'CPO', 'PID-Lag', 'CPPO-PID', 'PPO+EWC', 'Exp. Replay', 'Safe EWC']

    n = len(values)
    U_matrix = np.zeros((n, n))
    p_matrix = np.ones((n, n))

    for i in range(n):
        for j in range(i+1, n):
            stat, p = mannwhitneyu(values[i], values[j])
            U_matrix[i, j] = stat
            p_matrix[i, j] = p
            print(f'U={stat:.1f}, p={p:.4f} for {alg_list[i]} vs. {alg_list[j]}')

    plot_heatmap(p_matrix, alg_list, metric_name, U_matrix)

def plot_heatmap(matrix, labels, title, U_matrix):
    mask = np.tril(np.ones_like(matrix, dtype=bool))
    annotated_matrix = np.empty_like(matrix, dtype=object)

    for i in range(matrix.shape[0]):
        for j in range(matrix.shape[1]):
            annotated_matrix[i, j] = f"{U_matrix[i, j]:.0f}, {matrix[i, j]:.4f}"
                
    plt.figure(figsize=(10, 10))
    ax = sns.heatmap(matrix, mask=mask, annot=annotated_matrix, fmt="", cmap="coolwarm_r", xticklabels=labels, yticklabels=labels, cbar_kws={'label': 'p-value'})
    plt.title(f'{title} Mann-Whitney U Test Heatmap')

    # Overlay asterisks on boxes where p-value is below the threshold
    for i in range(matrix.shape[0]):
        for j in range(matrix.shape[1]):
            if matrix[i, j] < 0.05/21:
                ax.text(j + 0.5, i + 0.25, '**', color='black', ha='center', va='center', fontsize=20)
            elif matrix[i, j] < 0.05:
                ax.text(j + 0.5, i + 0.25, '*', color='black', ha='center', va='center', fontsize=20)

            

    plt.savefig(f'./results/plots/{title}_heatmap_ant', bbox_inches='tight')
    plt.show()

# %%
get_all_metrics()
# Out:
# Rewards
# U=88.0, p=0.0046 for PPO vs. CPO
# U=89.0, p=0.0036 for PPO vs. PID-Lag
# U=85.0, p=0.0091 for PPO vs. CPPO-PID
# U=47.0, p=0.8501 for PPO vs. PPO+EWC
# U=90.0, p=0.0003 for PPO vs. Exp. Replay
# U=86.0, p=0.0073 for PPO vs. Safe EWC
# U=50.0, p=1.0000 for CPO vs. PID-Lag
# U=32.0, p=0.1859 for CPO vs. CPPO-PID
# U=10.0, p=0.0028 for CPO vs. PPO+EWC
# U=90.0, p=0.0003 for CPO vs. Exp. Replay
# U=28.0, p=0.1041 for CPO vs. Safe EWC
# U=31.0, p=0.1620 for PID-Lag vs. CPPO-PID
# U=9.0, p=0.0022 for PID-Lag vs. PPO+EWC
# U=90.0, p=0.0003 for PID-Lag vs. Exp. Replay
# U=31.0, p=0.1620 for PID-Lag vs. Safe EWC
# U=9.0, p=0.0022 for CPPO-PID vs. PPO+EWC
# U=90.0, p=0.0003 for CPPO-PID vs. Exp. Replay
# U=51.0, p=0.9698 for CPPO-PID vs. Safe EWC
# U=90.0, p=0.0003 for PPO+EWC vs. Exp. Replay
# U=89.0, p=0.0036 for PPO+EWC vs. Safe EWC
# U=0.0, p=0.0003 for Exp. Replay vs. Safe EWC
# Normalized Forgetting
# U=10.0, p=0.0028 for PPO vs. CPO
# U=45.0, p=0.7337 for PPO vs. PID-Lag
# ...
