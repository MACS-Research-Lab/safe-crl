# %%
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd

import matplotlib.patches as mpatches
from matplotlib.lines import Line2D

# %% [markdown]
# # Half Cheetah Results

# %%
cheetah_cpo_0 = pd.read_csv('./results/cheetah/cpo_0.csv')
cheetah_cpo_1 = pd.read_csv('./results/cheetah/cpo_1.csv')
cheetah_cpo_2 = pd.read_csv('./results/cheetah/cpo_2.csv')
cheetah_cpo_3 = pd.read_csv('./results/cheetah/cpo_3.csv')
cheetah_cpo_4 = pd.read_csv('./results/cheetah/cpo_4.csv')

cpo_list = [cheetah_cpo_0, cheetah_cpo_1, cheetah_cpo_2, cheetah_cpo_3, cheetah_cpo_4]

cheetah_cpo_rewards = [results['Metrics/EpRet'] for results in cpo_list]
cheetah_cpo_costs = [results['Metrics/EpCost'] for results in cpo_list]

cheetah_cpo_mean_rewards = np.mean(cheetah_cpo_rewards, axis=0)
cheetah_cpo_mean_costs = np.mean(cheetah_cpo_costs, axis=0)

cheetah_cpo_std_rewards = np.std(cheetah_cpo_rewards, axis=0)
cheetah_cpo_std_costs = np.std(cheetah_cpo_costs, axis=0)

# %%
cheetah_ppo_0 = pd.read_csv('./results/cheetah/ppo_0.csv')
cheetah_ppo_1 = pd.read_csv('./results/cheetah/ppo_1.csv')
cheetah_ppo_2 = pd.read_csv('./results/cheetah/ppo_2.csv')
cheetah_ppo_3 = pd.read_csv('./results/cheetah/ppo_3.csv')
cheetah_ppo_4 = pd.read_csv('./results/cheetah/ppo_4.csv')

ppo_list = [cheetah_ppo_0, cheetah_ppo_1, cheetah_ppo_2, cheetah_ppo_3, cheetah_ppo_4]

cheetah_ppo_rewards = [results['Metrics/EpRet'] for results in ppo_list]
cheetah_ppo_costs = [results['Metrics/EpCost'] for results in ppo_list]

cheetah_ppo_mean_rewards = np.mean(cheetah_ppo_rewards, axis=0)
cheetah_ppo_mean_costs = np.mean(cheetah_ppo_costs, axis=0)

cheetah_ppo_std_rewards = np.std(cheetah_ppo_rewards, axis=0)
cheetah_ppo_std_costs = np.std(cheetah_ppo_costs, axis=0)

# %%
cheetah_ppolag_0 = pd.read_csv('./results/cheetah/ppo_lag_0.csv')
cheetah_ppolag_1 = pd.read_csv('./results/cheetah/ppo_lag_1.csv')
cheetah_ppolag_2 = pd.read_csv('./results/cheetah/ppo_lag_2.csv')
cheetah_ppolag_3 = pd.read_csv('./results/cheetah/ppo_lag_3.csv')
cheetah_ppolag_4 = pd.read_csv('./results/cheetah/ppo_lag_4.csv')

ppolag_list = [cheetah_ppolag_0, cheetah_ppolag_1, cheetah_ppolag_2, cheetah_ppolag_3, cheetah_ppolag_4]

cheetah_ppolag_rewards = [results['Metrics/EpRet'] for results in ppolag_list]
cheetah_ppolag_costs = [results['Metrics/EpCost'] for results in ppolag_list]

cheetah_ppolag_mean_rewards = np.mean(cheetah_ppolag_rewards, axis=0)
cheetah_ppolag_mean_costs = np.mean(cheetah_ppolag_costs, axis=0)

cheetah_ppolag_std_rewards = np.std(cheetah_ppolag_rewards, axis=0)
cheetah_ppolag_std_costs = np.std(cheetah_ppolag_costs, axis=0)

# %%
cheetah_cppo_pid_0 = pd.read_csv('./results/cheetah/cppo_0.csv')
cheetah_cppo_pid_1 = pd.read_csv('./results/cheetah/cppo_1.csv')
cheetah_cppo_pid_2 = pd.read_csv('./results/cheetah/cppo_2.csv')
cheetah_cppo_pid_3 = pd.read_csv('./results/cheetah/cppo_3.csv')
cheetah_cppo_pid_4 = pd.read_csv('./results/cheetah/cppo_4.csv')

cppo_pid_list = [cheetah_cppo_pid_0, cheetah_cppo_pid_1, cheetah_cppo_pid_2, cheetah_cppo_pid_3, cheetah_cppo_pid_4]

cheetah_cppo_pid_rewards = [results['Metrics/EpRet'] for results in cppo_pid_list]
cheetah_cppo_pid_costs = [results['Metrics/EpCost'] for results in cppo_pid_list]

cheetah_cppo_pid_mean_rewards = np.mean(cheetah_cppo_pid_rewards, axis=0)
cheetah_cppo_pid_mean_costs = np.mean(cheetah_cppo_pid_costs, axis=0)

cheetah_cppo_pid_std_rewards = np.std(cheetah_cppo_pid_rewards, axis=0)
cheetah_cppo_pid_std_costs = np.std(cheetah_cppo_pid_costs, axis=0)

# %%
cheetah_clear_0 = pd.read_csv('./results/cheetah/clear_0.csv')
cheetah_clear_1 = pd.read_csv('./results/cheetah/clear_1.csv')
cheetah_clear_2 = pd.read_csv('./results/cheetah/clear_2.csv')
cheetah_clear_3 = pd.read_csv('./results/cheetah/clear_3.csv')
cheetah_clear_4 = pd.read_csv('./results/cheetah/clear_4.csv')

clear_list = [cheetah_clear_0, cheetah_clear_1, cheetah_clear_2, cheetah_clear_3, cheetah_clear_4] 

cheetah_clear_rewards = [results['Metrics/EpRet'] for results in clear_list]
cheetah_clear_costs = [results['Metrics/EpCost'] for results in clear_list]

cheetah_clear_mean_rewards = np.mean(cheetah_clear_rewards, axis=0)
cheetah_clear_mean_costs = np.mean(cheetah_clear_costs, axis=0)

cheetah_clear_std_rewards = np.std(cheetah_clear_rewards, axis=0)
cheetah_clear_std_costs = np.std(cheetah_clear_costs, axis=0)

# %%
cf_ewc_0 = pd.read_csv('./results/cheetah/cf_ewc_0.csv')
cf_ewc_1 = pd.read_csv('./results/cheetah/cf_ewc_1.csv')
cf_ewc_2 = pd.read_csv('./results/cheetah/cf_ewc_2.csv')
cf_ewc_3 = pd.read_csv('./results/cheetah/cf_ewc_3.csv')
cf_ewc_4 = pd.read_csv('./results/cheetah/cf_ewc_4.csv')

cf_list = [cf_ewc_0, cf_ewc_1, cf_ewc_2, cf_ewc_3, cf_ewc_4]

cf_ewc_rewards = [results['Metrics/EpSuccess'] for results in cf_list]
cf_ewc_costs = [results['Metrics/EpCost'] for results in cf_list]

cf_ewc_mean_rewards = np.mean(cf_ewc_rewards, axis=0)
cf_ewc_mean_costs = np.mean(cf_ewc_costs, axis=0)

cf_ewc_std_rewards = np.std(cf_ewc_rewards, axis=0)
cf_ewc_std_costs = np.std(cf_ewc_costs, axis=0)

# %%
def aggregate_metrics(results_list, task_sequence, task_length):
    nominal_costs, back_costs, front_costs = [], [], []
    nominal_forgets, back_forgets, front_forgets = [], [], []
    nominal_rew_forgets, back_rew_forgets, front_rew_forgets = [], [], []
    nominal_rewards, back_rewards, front_rewards = [], [], []
    for result in results_list:
        nominal_cost, back_cost, front_cost, nominal_forget, back_forget, front_forget, nominal_rew, back_rew, front_rew, nominal_rew_forget, back_rew_forget, front_rew_forget = calculate_metrics(result, task_sequence, task_length)
        nominal_costs.append(nominal_cost)
        back_costs.append(back_cost)
        front_costs.append(front_cost)
        nominal_forgets.append(nominal_forget)
        back_forgets.append(back_forget) 
        front_forgets.append(front_forget)
        nominal_rewards.append(nominal_rew)
        back_rewards.append(back_rew)
        front_rewards.append(front_rew)
        nominal_rew_forgets.append(nominal_rew_forget)
        front_rew_forgets.append(front_rew_forget)
        back_rew_forgets.append(back_rew_forget)

    print("COSTS:")
    print(f'Nominal total costs: {np.mean(nominal_costs)} +/- {np.std(nominal_costs)}')
    print(f'Back total costs: {np.mean(back_costs)} +/- {np.std(back_costs)}')
    print(f'Front total costs: {np.mean(front_costs)} +/- {np.std(front_costs)}')
    print(f'Overall costs: {np.mean([np.mean(nominal_costs), np.mean(back_costs), np.mean(front_costs)])} ' 
          f'+/- {np.mean([np.std(nominal_costs), np.std(back_costs), np.std(front_costs)])}')

    print("FORGETTING RATIO:")
    print(f'Nominal forgetting: {np.mean(nominal_forgets)} +/- {np.std(nominal_forgets)}')
    print(f'Back forgetting: {np.mean(back_forgets)} +/- {np.std(back_forgets)}')
    print(f'Front forgetting: {np.mean(front_forgets)} +/- {np.std(front_forgets)}')
    print(f'Overall forgetting: {np.mean([np.mean(nominal_forgets), np.mean(back_forgets), np.mean(front_forgets)])} ' 
          f'+/- {np.mean([np.std(nominal_forgets), np.std(back_forgets), np.std(front_forgets)])}')
    
    print("REWARD FORGETTING:")
    print(f'Nominal forgetting: {np.mean(nominal_rew_forgets)} +/- {np.std(nominal_rew_forgets)}')
    print(f'Back forgetting: {np.mean(back_rew_forgets)} +/- {np.std(back_rew_forgets)}')
    print(f'Front forgetting: {np.mean(front_rew_forgets)} +/- {np.std(front_rew_forgets)}')
    print(f'Overall forgetting: {np.mean([np.mean(nominal_rew_forgets), np.mean(back_rew_forgets), np.mean(front_rew_forgets)])} ' 
          f'+/- {np.mean([np.std(nominal_rew_forgets), np.std(back_rew_forgets), np.std(front_rew_forgets)])}')
    
    initial = [r['Metrics/EpRet'][0] for r in results_list]
    possible_forgetting = np.mean([np.mean(nominal_rewards), np.mean(back_rewards), np.mean(front_rewards)]) - np.mean(initial)
    print(np.mean(initial), possible_forgetting)
    norm_forget = np.mean([np.mean(nominal_rew_forgets), np.mean(back_rew_forgets), np.mean(front_rew_forgets)]) / possible_forgetting
    print('NORMALIZED FORGETTING:')
    print(norm_forget)

    print("REWARDS:")
    print(f'Nominal rewards: {np.mean(nominal_rewards)} +/- {np.std(nominal_rewards)}')
    print(f'Back rewards: {np.mean(back_rewards)} +/- {np.std(back_rewards)}')
    print(f'Front rewards: {np.mean(front_rewards)} +/- {np.std(front_rewards)}')
    print(f'Overall rewards: {np.mean([np.mean(nominal_rewards), np.mean(back_rewards), np.mean(front_rewards)])} ' 
          f'+/- {np.mean([np.std(nominal_rewards), np.std(back_rewards), np.std(front_rewards)])}')

def calculate_metrics(results, task_sequence, task_length):
    results = add_task_names(results, task_sequence, task_length)
    nominal_cost, back_cost, front_cost = all_average_total_costs(results, task_length)
    nominal_forget, back_forget, front_forget, nominal_rew_forget, back_rew_forget, front_rew_forget = all_forgetting(results, task_length)
    nominal_rew, back_rew, front_rew = all_rewards(results, task_length)
    return nominal_cost, back_cost, front_cost, nominal_forget, back_forget, front_forget, nominal_rew, back_rew, front_rew, nominal_rew_forget, back_rew_forget, front_rew_forget

def add_task_names(results, task_sequence, task_length):
    task_names = [[task] * task_length for task in task_sequence]
    task_names = np.concatenate(task_names)
    results['task'] = task_names

    return results

def all_average_total_costs(results, task_length):
    nominal_cost = average_total_costs(results, 'nominal', task_length)
    back_cost = average_total_costs(results, 'back', task_length)
    front_cost = average_total_costs(results, 'front', task_length)

    return nominal_cost, back_cost, front_cost

def average_total_costs(results, task_name, task_length):
    task_results = results[results['task'] == task_name]
    task_costs = task_results['Metrics/EpCost'].to_numpy()

    num_visited = int(len(task_costs) / task_length)

    total_costs = []
    for i in range(num_visited):
        task_idx = np.arange(0, task_length) + i * task_length
        total_costs.append(task_costs[task_idx].sum())

    return np.mean(total_costs)

def all_forgetting(results, task_length):
    nominal_forget, nominal_rew_forget = forgetting(results, 'nominal', task_length)
    back_forget, back_rew_forget = forgetting(results, 'back', task_length)
    front_forget, front_rew_forget = forgetting(results, 'front', task_length)

    return nominal_forget, back_forget, front_forget, nominal_rew_forget, back_rew_forget, front_rew_forget

def forgetting(results, task_name, task_length):
    task_results = results[results['task'] == task_name]
    task_rewards = task_results['Metrics/EpRet'].to_numpy()

    endpoint = task_length - 1
    startpoint = task_length + 1 # to purge the buffer

    num_visited = int(len(task_rewards) / task_length)
    num_restart = num_visited - 1

    forget_values = []
    abs_forget = []
    for i in range(num_restart):
        A = task_rewards[endpoint * (i+1)]
        B = task_rewards[startpoint * (i+1)]
        forget = (A - B) / (np.abs(A)) * 100

        forget_values.append(forget)
        abs_forget.append(A-B)
    
    return np.mean(forget_values), np.mean(abs_forget)

def all_rewards(results, task_length):
    nominal_rew = rewards(results, 'nominal', task_length)
    back_rew = rewards(results, 'back', task_length)
    front_rew = rewards(results, 'front', task_length)

    return nominal_rew, back_rew, front_rew

def rewards(results, task_name, task_length):
    task_results = results[results['task'] == task_name]
    task_rewards = task_results['Metrics/EpRet'].to_numpy()

    endpoint = task_length - 1

    num_visited = int(len(task_rewards) / task_length)

    reward_vals = []
    for i in range(num_visited):
        rew = task_rewards[endpoint * (i+1)]
        reward_vals.append(rew)
    
    return reward_vals[-1]

# %%
def bootstrap_ci(data, num_samples=10000, ci=95):
    if len(data) == 0:
        return np.nan, np.nan
    bootstrapped_means = np.array([
        np.mean(np.random.choice(data, size=len(data), replace=True))
        for _ in range(num_samples)
    ])
    lower = np.percentile(bootstrapped_means, (100 - ci) / 2)
    upper = np.percentile(bootstrapped_means, 100 - (100 - ci) / 2)
    return lower, upper

def aggregate_metrics_bootstrap(results_list, task_sequence, task_length):
    nominal_costs, back_costs, front_costs = [], [], []
    nominal_forgets, back_forgets, front_forgets = [], [], []
    nominal_rew_forgets, back_rew_forgets, front_rew_forgets = [], [], []
    nominal_rewards, back_rewards, front_rewards = [], [], []

    for result in results_list:
        nominal_cost, back_cost, front_cost, nominal_forget, back_forget, front_forget, nominal_rew, back_rew, front_rew, nominal_rew_forget, back_rew_forget, front_rew_forget = calculate_metrics(result, task_sequence, task_length)
        nominal_costs.append(nominal_cost)
        back_costs.append(back_cost)
        front_costs.append(front_cost)
        nominal_forgets.append(nominal_forget)
        back_forgets.append(back_forget)
        front_forgets.append(front_forget)
        nominal_rewards.append(nominal_rew)
        back_rewards.append(back_rew)
        front_rewards.append(front_rew)
        nominal_rew_forgets.append(nominal_rew_forget)
        front_rew_forgets.append(front_rew_forget)
        back_rew_forgets.append(back_rew_forget)

    def print_metric(title, data_groups, labels):
        print(title)
        all_means = []
        for label, data in zip(labels, data_groups):
            mean = np.mean(data)
            lower, upper = bootstrap_ci(data)
            print(f'{label}: {mean:.3f} [{lower:.3f}, {upper:.3f}]')
            all_means.append(mean)
        overall_mean = np.mean(all_means)
        # Combine all data for bootstrapping overall
        combined = np.concatenate(data_groups)
        lower, upper = bootstrap_ci(combined)
        print(f'Overall: {overall_mean:.3f} [{lower:.3f}, {upper:.3f}]\n')

    print_metric("COSTS:", [nominal_costs, back_costs, front_costs], ["Nominal total costs", "Back total costs", "Front total costs"])
    print_metric("FORGETTING RATIO:", [nominal_forgets, back_forgets, front_forgets], ["Nominal forgetting", "Back forgetting", "Front forgetting"])
    print_metric("REWARD FORGETTING:", [nominal_rew_forgets, back_rew_forgets, front_rew_forgets], ["Nominal forgetting", "Back forgetting", "Front forgetting"])

    # print("NORMALIZED FORGETTING:")
    # initial = [r['Metrics/EpRet'][0] for r in results_list]
    # initial_mean = np.mean(initial)
    # mean_reward = np.mean([np.mean(nominal_rewards), np.mean(back_rewards), np.mean(front_rewards)])
    # possible_forgetting = mean_reward - initial_mean
    # mean_rew_forgetting = np.mean([np.mean(nominal_rew_forgets), np.mean(back_rew_forgets), np.mean(front_rew_forgets)])
    # norm_forget = mean_rew_forgetting / possible_forgetting if possible_forgetting != 0 else np.nan
    # print(f'{norm_forget:.3f} (initial mean: {initial_mean:.3f}, possible forgetting: {possible_forgetting:.3f})\n')


    initial = [r['Metrics/EpRet'][0] for r in results_list]
    mean_reward = np.mean(np.vstack([nominal_rewards, back_rewards, front_rewards]), axis=0)
    possible_forgetting = mean_reward - initial
    actual_forgetting = np.mean(np.vstack([nominal_rew_forgets, back_rew_forgets, front_rew_forgets]), axis=0)
    norm_forget = actual_forgetting / possible_forgetting 
    print_metric("Normalized Forgetting:", [norm_forget], ["Across tasks forgetting"])


    print_metric("REWARDS:", [nominal_rewards, back_rewards, front_rewards], ["Nominal rewards", "Back rewards", "Front rewards"])

# %%
tasks_encountered = ['nominal', 'back', 'nominal', 'front', 'back', 'nominal', 'front', 'nominal']


aggregate_metrics(cpo_list, tasks_encountered, 50)
# Out:
# COSTS:
# Nominal total costs: 832.2809957051679 +/- 89.42733754382556
# Back total costs: 615.3165000000001 +/- 200.59364318255453
# Front total costs: 39.032000000000004 +/- 38.71099803027558
# Overall costs: 495.543165235056 +/- 109.57732625221855
# FORGETTING RATIO:
# Nominal forgetting: 46.232600030436416 +/- 14.862780145665692
# Back forgetting: 126.351000177159 +/- 30.57639375408606
# Front forgetting: 114.80690354644555 +/- 21.347780314210198
# Overall forgetting: 95.79683458468031 +/- 22.26231807132065
# REWARD FORGETTING:
# Nominal forgetting: 813.0746734908613 +/- 271.6773221265852
# Back forgetting: 2077.692022094415 +/- 463.7547689918891
# Front forgetting: 976.4036499522488 +/- 162.71928492892948
# Overall forgetting: 1289.0567818458414 +/- 299.38379201580125
# -656.0368449793328 2192.3515603832097
# NORMALIZED FORGETTING:
# 0.5879790473114276
# REWARDS:
# Nominal rewards: 2075.9248071572347 +/- 97.09438398368117
# Back rewards: 1657.165037508375 +/- 92.77814374335371
# Front rewards: 875.8543015460209 +/- 170.29032996624548
# Overall rewards: 1536.3147154038768 +/- 120.05428589776011

# %%
tasks_encountered = ['nominal', 'back', 'nominal', 'front', 'back', 'nominal', 'front', 'nominal']


aggregate_metrics(clear_list, tasks_encountered, 50)
# Out:
# COSTS:
# Nominal total costs: 1871.4036250000001 +/- 3453.7761813982856
# Back total costs: 25.084 +/- 20.92117423807756
# Front total costs: 103.68825 +/- 70.9654953463301
# Overall costs: 666.7252916666667 +/- 1181.8876169942312
# FORGETTING RATIO:
# Nominal forgetting: 313.69929127366663 +/- 533.3383492683608
# Back forgetting: 1465.9919611791636 +/- 2365.055742273853
# Front forgetting: 63.721220039516446 +/- 16.906700919398858
# Overall forgetting: 614.4708241641156 +/- 971.7669308205374
# REWARD FORGETTING:
# Nominal forgetting: 219.8946356047166 +/- 118.53000341166994
# Back forgetting: 195.19892082804864 +/- 63.77722623576329
# Front forgetting: 183.54490747007526 +/- 52.95917685537309
# Overall forgetting: 199.54615463428016 +/- 78.42213550093544
# -649.3560863852265 1154.2553987334206
# NORMALIZED FORGETTING:
# 0.17287868426107839
# REWARDS:
# Nominal rewards: 883.4247667506095 +/- 615.7680615051099
# Back rewards: 210.46138153659166 +/- 221.12061512861757
# Front rewards: 420.81178875738095 +/- 47.21271228425134
# Overall rewards: 504.8993123481941 +/- 294.70046297265964

# %%
aggregate_metrics(ppolag_list, tasks_encountered, 50)
# Out:
# COSTS:
# Nominal total costs: 1611.4257499999999 +/- 591.4025206875019
# Back total costs: 803.4055000000001 +/- 658.4298787359592
# Front total costs: 76.92525000000002 +/- 110.16693445460396
# Overall costs: 830.5855000000001 +/- 453.33311129268833
# FORGETTING RATIO:
# Nominal forgetting: 19.85123023596902 +/- 21.98206327670138
# Back forgetting: 103.1949214614547 +/- 20.876632328183252
# Front forgetting: 71.81880940849705 +/- 42.42942411731127
# Overall forgetting: 64.95498703530693 +/- 28.429373240731966
# REWARD FORGETTING:
# Nominal forgetting: 283.84461058322995 +/- 220.1773125035845
# Back forgetting: 1138.593102975449 +/- 262.7228919299778
# Front forgetting: 455.2065206883984 +/- 282.7077601173572
# Overall forgetting: 625.8814114156925 +/- 255.20265485030652
# -649.3560863852265 2202.8856396238107
# NORMALIZED FORGETTING:
# 0.28411888486529646
# REWARDS:
# Nominal rewards: 2328.29343878548 +/- 343.642176570543
# Back rewards: 1293.8242678371996 +/- 369.2394868458095
# Front rewards: 1038.4709530930743 +/- 292.44973672855747
# Overall rewards: 1553.5295532385844 +/- 335.11046671496996

# %%
aggregate_metrics(cf_list, tasks_encountered, 50)
# Out:
# COSTS:
# Nominal total costs: 17037.155749999998 +/- 8953.20407396323
# Back total costs: 1426.6977499999998 +/- 1098.3274057283647
# Front total costs: 416.7077499999999 +/- 198.48185278413996
# Overall costs: 6293.520416666666 +/- 3416.6711108252453
# FORGETTING RATIO:
# Nominal forgetting: 34.95308344283417 +/- 18.69260017822128
# Back forgetting: 87.45694185190318 +/- 33.97723037321117
# Front forgetting: 26.807508650152794 +/- 20.30481318420352
# Overall forgetting: 49.73917798163004 +/- 24.324881245211994
# REWARD FORGETTING:
# Nominal forgetting: 709.0565993784969 +/- 293.04496171329737
# Back forgetting: 906.4049800734413 +/- 391.8203600371838
# Front forgetting: 190.59921230846652 +/- 120.61301995488871
# Overall forgetting: 602.0202639201349 +/- 268.4927805684566
# -649.3560863852265 2716.470829943767
# NORMALIZED FORGETTING:
# 0.22161852698142065
# REWARDS:
# Nominal rewards: 3460.385829243967 +/- 1039.5718693687563
# Back rewards: 1588.1880835122358 +/- 581.6243181730904
# Front rewards: 1152.770317919419 +/- 208.89756460604758
# Overall rewards: 2067.114743558541 +/- 610.0312507159648

# %%
aggregate_metrics(ppo_list, tasks_encountered, 50)
# Out:
# COSTS:
# Nominal total costs: 20006.78 +/- 7114.960809499407
# Back total costs: 1195.75675 +/- 660.9687350267599
# Front total costs: 902.5234999999999 +/- 501.56387272422745
# Overall costs: 7368.353416666666 +/- 2759.164472416798
# FORGETTING RATIO:
# Nominal forgetting: 18.921506871547646 +/- 11.04234579723138
# Back forgetting: 76.69095618973301 +/- 46.384185140190645
# Front forgetting: 31.0045241567981 +/- 8.422528041374234
# Overall forgetting: 42.205662406026256 +/- 21.94968632626542
# REWARD FORGETTING:
# Nominal forgetting: 590.6260018436375 +/- 274.9498309872404
# Back forgetting: 1124.3035305949045 +/- 745.1278633447603
# Front forgetting: 265.64701177321723 +/- 89.17124947610569
# Overall forgetting: 660.1921814039198 +/- 369.74964793603544
# -649.3560863852265 2728.205528536182
# NORMALIZED FORGETTING:
# 0.24198770015620696
# REWARDS:
# Nominal rewards: 3891.5315329028867 +/- 582.5337434134491
# Back rewards: 1088.7445040099064 +/- 811.2818939237418
# Front rewards: 1256.272289540073 +/- 283.7280747133453
# Overall rewards: 2078.8494421509554 +/- 559.1812373501787

# %%
aggregate_metrics(cppo_pid_list, tasks_encountered, 50)
# Out:
# COSTS:
# Nominal total costs: 1074.5518749999999 +/- 329.1149862455465
# Back total costs: 536.22 +/- 364.3910972559222
# Front total costs: 118.72975000000001 +/- 148.01700509443165
# Overall costs: 576.5005416666667 +/- 280.5076961986335
# FORGETTING RATIO:
# Nominal forgetting: 19.317262696363436 +/- 22.679009552965148
# Back forgetting: 86.73728275243612 +/- 46.97845154387281
# Front forgetting: 67.47373117920242 +/- 38.51738521607271
# Overall forgetting: 57.84275887600066 +/- 36.05828210430355
# REWARD FORGETTING:
# Nominal forgetting: 273.1852603723655 +/- 237.88771141989224
# Back forgetting: 870.6610890944003 +/- 479.3639230745878
# Front forgetting: 407.43106098050635 +/- 185.73534476828567
# Overall forgetting: 517.0924701490907 +/- 300.9956597542552
# -649.3560863852265 2137.1719963538535
# NORMALIZED FORGETTING:
# 0.24195173389473665
# REWARDS:
# Nominal rewards: 2311.4612608312 +/- 340.7107504629227
# Back rewards: 1199.3047674590853 +/- 309.3402688798798
# Front rewards: 952.6817016155952 +/- 340.5107066195795
# Overall rewards: 1487.815909968627 +/- 330.1872419874606

# %%
cheetah_ewc_0 = pd.read_csv('./results/cheetah/ppo_ewc_0.csv')
cheetah_ewc_1 = pd.read_csv('./results/cheetah/ppo_ewc_1.csv')
cheetah_ewc_2 = pd.read_csv('./results/cheetah/ppo_ewc_2.csv')
cheetah_ewc_3 = pd.read_csv('./results/cheetah/ppo_ewc_3.csv')
cheetah_ewc_4 = pd.read_csv('./results/cheetah/ppo_ewc_4.csv')

ewc_list = [cheetah_ewc_0, cheetah_ewc_1, cheetah_ewc_2, cheetah_ewc_3, cheetah_ewc_4]

cheetah_ewc_rewards = [results['Metrics/EpRet'] for results in ewc_list]
cheetah_ewc_costs = [results['Metrics/EpCost'] for results in ewc_list]

cheetah_ewc_mean_rewards = np.mean(cheetah_ewc_rewards, axis=0)
cheetah_ewc_mean_costs = np.mean(cheetah_ewc_costs, axis=0)

cheetah_ewc_std_rewards = np.std(cheetah_ewc_rewards, axis=0)
cheetah_ewc_std_costs = np.std(cheetah_ewc_costs, axis=0)

# %%
aggregate_metrics(ewc_list, tasks_encountered, 50)
# Out:
# COSTS:
# Nominal total costs: 17594.279374999995 +/- 9204.501130174489
# Back total costs: 1017.403 +/- 545.2185801203954
# Front total costs: 656.25475 +/- 679.3547254460478
# Overall costs: 6422.645708333331 +/- 3476.3581452469775
# FORGETTING RATIO:
# Nominal forgetting: 36.68955908149217 +/- 29.446731742372293
# Back forgetting: 77.88359639768748 +/- 35.93384901208341
# Front forgetting: 43.943488926185225 +/- 12.724195258374124
# Overall forgetting: 52.838881468454964 +/- 26.034925337609945
# REWARD FORGETTING:
# Nominal forgetting: 694.2073501849869 +/- 396.6273372892384
# Back forgetting: 902.9906857179583 +/- 475.0189710976908
# Front forgetting: 349.7853097648612 +/- 131.3154303861218
# Overall forgetting: 648.9944485559355 +/- 334.32057959101695
# -649.3560863852265 2685.9581328649497
# NORMALIZED FORGETTING:
# 0.24162493101249208
# REWARDS:
# Nominal rewards: 3598.5957501498933 +/- 1149.3973028149346
# Back rewards: 1400.637918852854 +/- 358.6884296696086
# Front rewards: 1110.5724704364216 +/- 159.66930714556017
# Overall rewards: 2036.6020464797232 +/- 555.9183465433679

# %%
cheetah_ewc_loss_0 = pd.read_csv('./results/cheetah/ewc_cost_loss_0.csv')
cheetah_ewc_loss_1 = pd.read_csv('./results/cheetah/ewc_cost_loss_1.csv')
cheetah_ewc_loss_2 = pd.read_csv('./results/cheetah/ewc_cost_loss_2.csv')
cheetah_ewc_loss_3 = pd.read_csv('./results/cheetah/ewc_cost_loss_3.csv')
cheetah_ewc_loss_4 = pd.read_csv('./results/cheetah/ewc_cost_loss_4.csv')

ewc_loss_list = [cheetah_ewc_loss_0, cheetah_ewc_loss_1, cheetah_ewc_loss_2, cheetah_ewc_loss_3, cheetah_ewc_loss_4]

cheetah_ewc_loss_rewards = [results['Metrics/EpRet'] for results in ewc_loss_list]
cheetah_ewc_loss_costs = [results['Metrics/EpCost'] for results in ewc_loss_list]

cheetah_ewc_loss_mean_rewards = np.mean(cheetah_ewc_loss_rewards, axis=0)
cheetah_ewc_loss_mean_costs = np.mean(cheetah_ewc_loss_costs, axis=0)

cheetah_ewc_loss_std_rewards = np.std(cheetah_ewc_loss_rewards, axis=0)
cheetah_ewc_loss_std_costs = np.std(cheetah_ewc_loss_costs, axis=0)

# %%
aggregate_metrics(ewc_loss_list, tasks_encountered, 50)
# Out:
# COSTS:
# Nominal total costs: 17594.279374999995 +/- 9204.501130174489
# Back total costs: 1017.403 +/- 545.2185801203954
# Front total costs: 656.25475 +/- 679.3547254460478
# Overall costs: 6422.645708333331 +/- 3476.3581452469775
# FORGETTING RATIO:
# Nominal forgetting: 36.68955908149217 +/- 29.446731742372293
# Back forgetting: 77.88359639768748 +/- 35.93384901208341
# Front forgetting: 43.943488926185225 +/- 12.724195258374124
# Overall forgetting: 52.838881468454964 +/- 26.034925337609945
# REWARD FORGETTING:
# Nominal forgetting: 694.2073501849869 +/- 396.6273372892384
# Back forgetting: 902.9906857179583 +/- 475.0189710976908
# Front forgetting: 349.7853097648612 +/- 131.3154303861218
# Overall forgetting: 648.9944485559355 +/- 334.32057959101695
# -649.3560863852265 2685.9581328649497
# NORMALIZED FORGETTING:
# 0.24162493101249208
# REWARDS:
# Nominal rewards: 3598.5957501498933 +/- 1149.3973028149346
# Back rewards: 1400.637918852854 +/- 358.6884296696086
# Front rewards: 1110.5724704364216 +/- 159.66930714556017
# Overall rewards: 2036.6020464797232 +/- 555.9183465433679

# %%
def convert_reward(safe_ewc):
    safe_ewc['Metrics/EpRet'] += 5* safe_ewc['Metrics/EpCost']
    return safe_ewc

# %%
safe_ewc_0 = convert_reward(pd.read_csv('./results/cheetah/ppo_ewc_cost_0.csv'))
safe_ewc_1 = convert_reward(pd.read_csv('./results/cheetah/ppo_ewc_cost_1.csv'))
safe_ewc_2 = convert_reward(pd.read_csv('./results/cheetah/ppo_ewc_cost_2.csv'))
safe_ewc_3 = convert_reward(pd.read_csv('./results/cheetah/ppo_ewc_cost_3.csv'))
safe_ewc_4 = convert_reward(pd.read_csv('./results/cheetah/ppo_ewc_cost_4.csv'))

safe_ewc_list = [safe_ewc_0, safe_ewc_1, safe_ewc_2, safe_ewc_3, safe_ewc_4]

safe_ewc_rewards = [results['Metrics/EpRet'] for results in safe_ewc_list]
safe_ewc_costs = [results['Metrics/EpCost'] for results in safe_ewc_list]

safe_ewc_mean_rewards = np.mean(safe_ewc_rewards, axis=0)
safe_ewc_mean_costs = np.mean(safe_ewc_costs, axis=0)

safe_ewc_std_rewards = np.std(safe_ewc_rewards, axis=0)
safe_ewc_std_costs = np.std(safe_ewc_costs, axis=0)

# %%
aggregate_metrics(safe_ewc_list, tasks_encountered, 50)
# Out:
# COSTS:
# Nominal total costs: 433.275875 +/- 137.69735394073936
# Back total costs: 387.3485 +/- 606.9138519630484
# Front total costs: 358.71725000000004 +/- 612.5964836932833
# Overall costs: 393.113875 +/- 452.4025631990237
# FORGETTING RATIO:
# Nominal forgetting: 26.08949638995216 +/- 22.01272414067302
# Back forgetting: 80.69109586003461 +/- 29.056044916827677
# Front forgetting: 21.496942976087706 +/- 21.57322396337053
# Overall forgetting: 42.75917840869149 +/- 24.21399767362374
# REWARD FORGETTING:
# Nominal forgetting: 363.1768224962035 +/- 203.7580576374906
# Back forgetting: 703.4351066791277 +/- 412.7596247664172
# Front forgetting: 165.0978250562116 +/- 185.92638346303315
# Overall forgetting: 410.56991807718094 +/- 267.4813552889803
# -649.3560863852265 2280.6463359634054
# NORMALIZED FORGETTING:
# 0.18002349228941072
# REWARDS:
# Nominal rewards: 2449.718172562524 +/- 178.79917254531216
# Back rewards: 1378.8614110318363 +/- 342.28365201745135
# Front rewards: 1065.2911651401769 +/- 200.8304796200811
# Overall rewards: 1631.290249578179 +/- 240.63776806094822

# %%
def plot_rewards(algorithms, ymax=None, save=False, name=None, bigger=False):
    if bigger:
        fig, ax = plt.subplots(figsize=(10,3))
    else:
        fig, ax = plt.subplots(figsize=(10,1))

    TASK_CYCLE = ['nominal', 'back', 'nominal', 'front', 'back', 'nominal', 'front']
    algorithm_colors={'PPO+EWC': 'blue', 
                    'CPO': 'purple',
                    'Safe EWC': 'green',
                    'PPO-Lag': 'orange',
                    'CPPO-PID': 'red',
                    'PPO': 'black',
                    'Exp. Replay': 'brown',
                    'CF': 'brown'}
    cycle_colors = {
        'nominal': 'blue',
        'back': 'orange',
        'front': 'red'
    }

    cycle_hatches = {
        'nominal': '',
        'back': 'oo',
        'front': 'xx'
    }

    if 'PPO+EWC' in algorithms:
        plt.plot(cheetah_cpo_0['Train/TotalSteps'], cheetah_ewc_mean_rewards, label='PPO+EWC', color='blue')
        plt.fill_between(
            cheetah_cpo_0['Train/TotalSteps'],
            cheetah_ewc_mean_rewards - cheetah_ewc_std_rewards,
            cheetah_ewc_mean_rewards + cheetah_ewc_std_rewards,
            color='blue', alpha=0.2
        )

    if 'CPO' in algorithms:
        plt.plot(cheetah_cpo_0['Train/TotalSteps'], cheetah_cpo_mean_rewards, label='CPO', color='purple')
        plt.fill_between(
            cheetah_cpo_0['Train/TotalSteps'],
            cheetah_cpo_mean_rewards - cheetah_cpo_std_rewards,
            cheetah_cpo_mean_rewards + cheetah_cpo_std_rewards,
            color='purple', alpha=0.2
        )

    if 'Safe EWC' in algorithms:
        plt.plot(cheetah_cpo_0['Train/TotalSteps'], safe_ewc_mean_rewards, label='Safe EWC', color='green')
        plt.fill_between(
            cheetah_cpo_0['Train/TotalSteps'],
            safe_ewc_mean_rewards - safe_ewc_std_rewards,
            safe_ewc_mean_rewards + safe_ewc_std_rewards,
            color='green', alpha=0.2
        )

    if 'PPO-Lag' in algorithms:
        plt.plot(cheetah_ppolag_0['Train/TotalSteps'], cheetah_ppolag_mean_rewards, label='PPO-Lag', color='orange')
        plt.fill_between(
            cheetah_ppolag_0['Train/TotalSteps'],
            cheetah_ppolag_mean_rewards - cheetah_ppolag_std_rewards,
            cheetah_ppolag_mean_rewards + cheetah_ppolag_std_rewards,
            color='orange', alpha=0.2
        )

    if 'CPPO-PID' in algorithms:
        plt.plot(cheetah_cppo_pid_0['Train/TotalSteps'], cheetah_cppo_pid_mean_rewards, label='CPPO-PID', color='red', alpha=0.5)
        plt.fill_between(
            cheetah_cppo_pid_0['Train/TotalSteps'],
            cheetah_cppo_pid_mean_rewards - cheetah_cppo_pid_std_rewards,
            cheetah_cppo_pid_mean_rewards + cheetah_cppo_pid_std_rewards,
            color='red', alpha=0.2
        )

    if 'PPO' in algorithms:
        plt.plot(cheetah_ppo_0['Train/TotalSteps'], cheetah_ppo_mean_rewards, label='PPO', color='black', alpha=0.5)
        plt.fill_between(
            cheetah_ppo_0['Train/TotalSteps'],
            cheetah_ppo_mean_rewards - cheetah_ppo_std_rewards,
            cheetah_ppo_mean_rewards + cheetah_ppo_std_rewards,
            color='black', alpha=0.2
        )

    if 'Exp. Replay' in algorithms:
        plt.plot(cheetah_clear_0['Train/TotalSteps'], cheetah_clear_mean_rewards, label='Exp. Replay', color='brown', alpha=0.5)
        plt.fill_between(
            cheetah_clear_0['Train/TotalSteps'],
            cheetah_clear_mean_rewards - cheetah_clear_std_rewards,
            cheetah_clear_mean_rewards + cheetah_clear_std_rewards,
            color='brown', alpha=0.2
        )

    if 'CF' in algorithms:
        plt.plot(cheetah_ppo_0['Train/TotalSteps'], cf_ewc_mean_rewards, label='CF-EWC', color='brown', alpha=0.5)
        plt.fill_between(
            cf_ewc_0['Train/TotalSteps'],
            cf_ewc_mean_rewards - cf_ewc_std_rewards,
            cf_ewc_mean_rewards + cf_ewc_std_rewards,
            color='brown', alpha=0.2
        )

    x_vals = range(0, max(cheetah_cpo_0['Train/TotalSteps']) + 1, 1000000)
    for i, x in enumerate(x_vals[:-1]):  # Exclude the last x-value as it doesn't define a region
        # Get the current task from the cycle
        task = TASK_CYCLE[i % len(TASK_CYCLE)]
        
        # Shade the region between the current and next x value
        plt.axvline(x=x, color='gray', linestyle='--', linewidth=1)
        plt.fill_between([x, x_vals[i + 1]], cheetah_ewc_0['Metrics/EpRet'].min(), cheetah_ewc_0['Metrics/EpRet'].max(), color=cycle_colors[task],  hatch=cycle_hatches[task], alpha=0.1)

    plt.axvline(x=0, color='gray', linestyle='--', linewidth=1, label='Task Change')

    legend_patches = []
    for task in cycle_colors:
        patch = mpatches.Patch(
            facecolor=cycle_colors[task], 
            hatch=cycle_hatches[task], 
            label=task,
            edgecolor='gray',  # Optional: add edgecolor to improve visibility in legend,
            alpha=0.3
        )
        legend_patches.append(patch)

    for algorithm in algorithms:
        custom_line = Line2D([0], [0], color=algorithm_colors[algorithm], lw=2, linestyle='-', label=algorithm.upper())
        legend_patches.append(custom_line)
    # Add legend to the plot, some options commented for generating concise paper figures
    if bigger:
        plt.legend(handles=legend_patches, title='Task/Algorithm', loc='lower center', bbox_to_anchor=(0.5, -0.5), ncol=5, shadow=True, columnspacing=0.6)
    else:
        plt.legend(handles=legend_patches, title='Task/Algorithm', loc='lower center', bbox_to_anchor=(0.5, -1.1), ncol=6, shadow=True, columnspacing=0.6)

    # plt.xlabel("Training Timesteps")
    plt.ylabel("Reward")
    plt.title("Damaged HalfCheetah Velocity")
    if ymax is not None:
        plt.ylim(-670, ymax)

    plt.xlim(0, 8_000_000)
    # from matplotlib.ticker import ScalarFormatter

    # ax.yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
    # ax.ticklabel_format(style='sci', axis='y', scilimits=(0, 0))  # Apply scientific notation to y-axis

    if save:
        plt.savefig(f'./results/plots/{name}.png', bbox_inches='tight')

# %%
algorithms = ['Safe EWC', 'CPO', 'CPPO-PID']
# algorithms = ['Safe EWC', 'CPO']
plot_rewards(algorithms, 2750, True, 'reward_halfcheetah')

# %%
algorithms = ['PPO+EWC', 'CPO', 'Safe EWC', 'PPO-Lag', 'CPPO-PID', 'PPO', 'Exp. Replay']
for algorithm in algorithms:
    plot_rewards([algorithm], 4500, True, f'{algorithm}_halfcheetah_reward', bigger=True)

# %%
plot_rewards(algorithms, 4500, True, f'all_halfcheetah_reward', bigger=True)

# %%
def plot_costs(algorithms, ymax=None, save=False, name=None):
    plt.figure(figsize=(10,3))

    TASK_CYCLE = ['nominal', 'back', 'nominal', 'front', 'back', 'nominal', 'front']
    algorithm_colors={'PPO+EWC': 'blue', 
                    'CPO': 'orange',
                    'Safe EWC': 'green',
                    'PPO-Lag': 'purple',
                    'CPPO-PID': 'red',
                    'PPO': 'black',
                    'Exp. Replay': 'brown',
                    'CF': 'brown'}
    cycle_colors = {
        'nominal': 'blue',
        'back': 'orange',
        'front': 'red'
    }

    cycle_hatches = {
        'nominal': '',
        'back': 'oo',
        'front': 'xx'
    }

    if 'PPO+EWC' in algorithms:
        plt.plot(cheetah_cpo_0['Train/TotalSteps'], cheetah_ewc_mean_costs, label='PPO+EWC', color='blue')
        plt.fill_between(
            cheetah_cpo_0['Train/TotalSteps'],
            cheetah_ewc_mean_costs - cheetah_ewc_std_costs,
            cheetah_ewc_mean_costs + cheetah_ewc_std_costs,
            color='blue', alpha=0.2
        )

    if 'CPO' in algorithms:
        plt.plot(cheetah_cpo_0['Train/TotalSteps'], cheetah_cpo_mean_costs, label='CPO', color='orange')
        plt.fill_between(
            cheetah_cpo_0['Train/TotalSteps'],
            cheetah_cpo_mean_costs - cheetah_cpo_std_costs,
            cheetah_cpo_mean_costs + cheetah_cpo_std_costs,
            color='orange', alpha=0.2
        )

    if 'Safe EWC' in algorithms:
        plt.plot(cheetah_cpo_0['Train/TotalSteps'], safe_ewc_mean_costs, label='Safe EWC', color='green')
        plt.fill_between(
            cheetah_cpo_0['Train/TotalSteps'],
            safe_ewc_mean_costs - safe_ewc_std_costs,
            safe_ewc_mean_costs + safe_ewc_std_costs,
            color='green', alpha=0.2
        )

    if 'PPO-Lag' in algorithms:
        plt.plot(cheetah_ppolag_0['Train/TotalSteps'], cheetah_ppolag_mean_costs, label='PPO-Lag', color='purple')
        plt.fill_between(
            cheetah_ppolag_0['Train/TotalSteps'],
            cheetah_ppolag_mean_costs - cheetah_ppolag_std_costs,
            cheetah_ppolag_mean_costs + cheetah_ppolag_std_costs,
            color='purple', alpha=0.2
        )

    if 'CPPO-PID' in algorithms:
        plt.plot(cheetah_cppo_pid_0['Train/TotalSteps'], cheetah_cppo_pid_mean_costs, label='CPPO-PID', color='red', alpha=0.5)
        plt.fill_between(
            cheetah_cppo_pid_0['Train/TotalSteps'],
            cheetah_cppo_pid_mean_costs - cheetah_cppo_pid_std_costs,
            cheetah_cppo_pid_mean_costs + cheetah_cppo_pid_std_costs,
            color='red', alpha=0.2
        )

    if 'PPO' in algorithms:
        plt.plot(cheetah_ppo_0['Train/TotalSteps'], cheetah_ppo_mean_costs, label='PPO', color='black', alpha=0.5)
        plt.fill_between(
            cheetah_ppo_0['Train/TotalSteps'],
            cheetah_ppo_mean_costs - cheetah_ppo_std_costs,
            cheetah_ppo_mean_costs + cheetah_ppo_std_costs,
            color='black', alpha=0.2
        )

    if 'Exp. Replay' in algorithms:
        plt.plot(cheetah_clear_0['Train/TotalSteps'], cheetah_clear_mean_costs, label='Exp. Replay', color='brown', alpha=0.5)
        plt.fill_between(
            cheetah_clear_0['Train/TotalSteps'],
            cheetah_clear_mean_costs - cheetah_clear_std_costs,
            cheetah_clear_mean_costs + cheetah_clear_std_costs,
            color='brown', alpha=0.2
        )

    if 'CF' in algorithms:
        plt.plot(cheetah_ppo_0['Train/TotalSteps'], cf_ewc_mean_costs, label='CF-EWC', color='brown', alpha=0.5)
        plt.fill_between(
            cheetah_ppo_0['Train/TotalSteps'],
            cf_ewc_mean_costs - cf_ewc_std_costs,
            cf_ewc_mean_costs + cf_ewc_std_costs,
            color='brown', alpha=0.2
        )

    x_vals = range(0, max(cheetah_cpo_0['Train/TotalSteps']) + 1, 1000000)
    for i, x in enumerate(x_vals[:-1]):  # Exclude the last x-value as it doesn't define a region
        # Get the current task from the cycle
        task = TASK_CYCLE[i % len(TASK_CYCLE)]
        
        # Shade the region between the current and next x value
        plt.axvline(x=x, color='gray', linestyle='--', linewidth=1)
        plt.fill_between([x, x_vals[i + 1]], cheetah_ewc_0['Metrics/EpCost'].min(), cheetah_ewc_0['Metrics/EpCost'].max(), color=cycle_colors[task],  hatch=cycle_hatches[task], alpha=0.1)

    plt.axvline(x=0, color='gray', linestyle='--', linewidth=1, label='Task Change')

    legend_patches = []
    for task in cycle_colors:
        patch = mpatches.Patch(
            facecolor=cycle_colors[task], 
            hatch=cycle_hatches[task], 
            label=task,
            edgecolor='gray',  # Optional: add edgecolor to improve visibility in legend,
            alpha=0.3
        )
        legend_patches.append(patch)

    for algorithm in algorithms:
        custom_line = Line2D([0], [0], color=algorithm_colors[algorithm], lw=2, linestyle='--', label=algorithm.upper())
        legend_patches.append(custom_line)
    # Add legend to the plot
    plt.legend(handles=legend_patches, title='Task/Algorithm', loc='lower center', bbox_to_anchor=(0.5, -0.55), ncol=5, shadow=True, columnspacing=0.6)


    plt.xlabel("Training Timesteps")
    plt.ylabel("Cost")
    plt.title("Damaged HalfCheetah Velocity")
    if ymax is not None:
        plt.ylim(0.5, ymax)
    plt.yscale('log')

    if save:
        plt.savefig(f'./results/plots/{name}.png', bbox_inches='tight')

# %%
plot_costs(algorithms, 1000, True, 'all_halfcheetah_cost')

# %%
algorithms = ['PPO+EWC', 'CPO', 'Safe EWC', 'PPO-Lag', 'CPPO-PID', 'PPO', 'Exp. Replay']
for algorithm in algorithms:
    plot_costs([algorithm], 1000, True, f'{algorithm}_halfcheetah_cost')

# %% [markdown]
# ## Statistical Analysis

# %%
from scipy.stats import mannwhitneyu
from scipy.stats import PermutationMethod
import seaborn as sns

def get_metrics(results_list, task_sequence, task_length):
    nominal_costs, back_costs, front_costs = [], [], []
    nominal_forgets, back_forgets, front_forgets = [], [], []
    nominal_rew_forgets, back_rew_forgets, front_rew_forgets = [], [], []
    nominal_rewards, back_rewards, front_rewards = [], [], []

    for result in results_list:
        nominal_cost, back_cost, front_cost, nominal_forget, back_forget, front_forget, nominal_rew, back_rew, front_rew, nominal_rew_forget, back_rew_forget, front_rew_forget = calculate_metrics(result, task_sequence, task_length)
        nominal_costs.append(nominal_cost)
        back_costs.append(back_cost)
        front_costs.append(front_cost)
        nominal_forgets.append(nominal_forget)
        back_forgets.append(back_forget)
        front_forgets.append(front_forget)
        nominal_rewards.append(nominal_rew)
        back_rewards.append(back_rew)
        front_rewards.append(front_rew)
        nominal_rew_forgets.append(nominal_rew_forget)
        front_rew_forgets.append(front_rew_forget)
        back_rew_forgets.append(back_rew_forget)

    initial = [r['Metrics/EpRet'][0] for r in results_list]
    mean_reward = np.mean(np.vstack([nominal_rewards, back_rewards, front_rewards]), axis=0)
    possible_forgetting = mean_reward - initial
    actual_forgetting = np.mean(np.vstack([nominal_rew_forgets, back_rew_forgets, front_rew_forgets]), axis=0)
    norm_forget = actual_forgetting / possible_forgetting 

    rewards = np.vstack([nominal_rewards, front_rewards, back_rewards]).mean(axis=0)
    costs = np.vstack([nominal_costs, front_costs, back_costs]).mean(axis=0)
    exact_forgets = np.vstack([nominal_forgets, front_forgets, back_forgets]).mean(axis=0)

    return rewards, norm_forget, costs, exact_forgets

def get_all_metrics():
    ppo_rew, ppo_forget, ppo_cost, ppo_raw_forget = get_metrics(ppo_list, tasks_encountered, 50)
    cpo_rew, cpo_forget, cpo_cost, cpo_raw_forget = get_metrics(cpo_list, tasks_encountered, 50)
    cppo_pid_rew, cppo_pid_forget, cppo_pid_cost, cppo_pid_raw_forget = get_metrics(cppo_pid_list, tasks_encountered, 50)
    ppo_lag_rew, ppo_lag_forget, ppo_lag_cost, ppo_lag_raw_forget = get_metrics(ppolag_list, tasks_encountered, 50)
    ewc_rew, ewc_forget, ewc_cost, ewc_raw_forget = get_metrics(ewc_list, tasks_encountered, 50)
    clear_rew, clear_forget, clear_cost, clear_raw_forget = get_metrics(clear_list, tasks_encountered, 50)
    safe_ewc_rew, safe_ewc_forget, safe_ewc_cost, safe_ewc_raw_forget = get_metrics(safe_ewc_list, tasks_encountered, 50)

    print('Rewards')
    rews = [ppo_rew, cpo_rew, cppo_pid_rew, ppo_lag_rew, ewc_rew, clear_rew, safe_ewc_rew]
    test_metric(rews, 'Rewards')
    print('')

    print('Normalized Forgetting')
    forgets = [ppo_forget, cpo_forget, cppo_pid_forget, ppo_lag_forget, ewc_forget, clear_forget, safe_ewc_forget]
    test_metric(forgets, 'Normalized Forgetting')
    print('')

    print('Costs')
    costs = [ppo_cost, cpo_cost, cppo_pid_cost, ppo_lag_cost, ewc_cost, clear_cost, safe_ewc_cost]
    test_metric(costs, 'Costs')
    print('')

def test_metric(values, metric_name):
    alg_list = ['PPO', 'CPO', 'PID-Lag', 'CPPO-PID', 'PPO+EWC', 'Exp. Replay', 'Safe EWC']

    n = len(values)
    U_matrix = np.zeros((n, n))
    p_matrix = np.ones((n, n))

    for i in range(n):
        for j in range(i+1, n):
            stat, p = mannwhitneyu(values[i], values[j])
            U_matrix[i, j] = stat
            p_matrix[i, j] = p
            print(f'U={stat:.1f}, p={p:.4f} for {alg_list[i]} vs. {alg_list[j]}')

    plot_heatmap(p_matrix, alg_list, metric_name, U_matrix)

def plot_heatmap(matrix, labels, title, U_matrix):
    mask = np.tril(np.ones_like(matrix, dtype=bool))
    annotated_matrix = np.empty_like(matrix, dtype=object)

    for i in range(matrix.shape[0]):
        for j in range(matrix.shape[1]):
            annotated_matrix[i, j] = f"{U_matrix[i, j]:.0f}, {matrix[i, j]:.4f}"
                
    plt.figure(figsize=(10, 10))
    ax = sns.heatmap(matrix, mask=mask, annot=annotated_matrix, fmt="", cmap="coolwarm_r", xticklabels=labels, yticklabels=labels, cbar_kws={'label': 'p-value'})
    plt.title(f'{title} Mann-Whitney U Test Heatmap')

    # Overlay asterisks on boxes where p-value is below the threshold
    for i in range(matrix.shape[0]):
        for j in range(matrix.shape[1]):
            if matrix[i, j] < 0.05/21:
                ax.text(j + 0.5, i + 0.25, '**', color='black', ha='center', va='center', fontsize=20)
            elif matrix[i, j] < 0.05:
                ax.text(j + 0.5, i + 0.25, '*', color='black', ha='center', va='center', fontsize=20)

            

    plt.savefig(f'./results/plots/{title}_heatmap_cheetah', bbox_inches='tight')
    plt.show()

# %%
get_all_metrics()
# Out:
# Rewards
# U=25.0, p=0.0079 for PPO vs. CPO
# U=24.0, p=0.0159 for PPO vs. PID-Lag
# U=22.0, p=0.0556 for PPO vs. CPPO-PID
# U=11.0, p=0.8413 for PPO vs. PPO+EWC
# U=25.0, p=0.0079 for PPO vs. Exp. Replay
# U=23.0, p=0.0317 for PPO vs. Safe EWC
# U=8.0, p=0.4206 for CPO vs. PID-Lag
# U=6.0, p=0.2222 for CPO vs. CPPO-PID
# U=5.0, p=0.1508 for CPO vs. PPO+EWC
# U=25.0, p=0.0079 for CPO vs. Exp. Replay
# U=6.0, p=0.2222 for CPO vs. Safe EWC
# U=8.0, p=0.4206 for PID-Lag vs. CPPO-PID
# U=4.0, p=0.0952 for PID-Lag vs. PPO+EWC
# U=25.0, p=0.0079 for PID-Lag vs. Exp. Replay
# U=9.0, p=0.5476 for PID-Lag vs. Safe EWC
# U=4.0, p=0.0952 for CPPO-PID vs. PPO+EWC
# U=25.0, p=0.0079 for CPPO-PID vs. Exp. Replay
# U=13.0, p=1.0000 for CPPO-PID vs. Safe EWC
# U=25.0, p=0.0079 for PPO+EWC vs. Exp. Replay
# U=20.0, p=0.1508 for PPO+EWC vs. Safe EWC
# U=0.0, p=0.0079 for Exp. Replay vs. Safe EWC
# Normalized Forgetting
# U=1.0, p=0.0159 for PPO vs. CPO
# U=12.0, p=1.0000 for PPO vs. PID-Lag
# U=9.0, p=0.5476 for PPO vs. CPPO-PID
# U=9.0, p=0.5476 for PPO vs. PPO+EWC
# U=18.0, p=0.3095 for PPO vs. Exp. Replay
# U=17.0, p=0.4206 for PPO vs. Safe EWC
# U=24.0, p=0.0159 for CPO vs. PID-Lag
# U=24.0, p=0.0159 for CPO vs. CPPO-PID
# U=25.0, p=0.0079 for CPO vs. PPO+EWC
# U=25.0, p=0.0079 for CPO vs. Exp. Replay
# U=25.0, p=0.0079 for CPO vs. Safe EWC
# U=10.0, p=0.6905 for PID-Lag vs. CPPO-PID
# U=11.0, p=0.8413 for PID-Lag vs. PPO+EWC
# U=17.0, p=0.4206 for PID-Lag vs. Exp. Replay
# U=16.0, p=0.5476 for PID-Lag vs. Safe EWC
# U=13.0, p=1.0000 for CPPO-PID vs. PPO+EWC
# U=18.0, p=0.3095 for CPPO-PID vs. Exp. Replay
# U=20.0, p=0.1508 for CPPO-PID vs. Safe EWC
# U=21.0, p=0.0952 for PPO+EWC vs. Exp. Replay
# U=20.0, p=0.1508 for PPO+EWC vs. Safe EWC
# U=12.0, p=1.0000 for Exp. Replay vs. Safe EWC
# Costs
# U=25.0, p=0.0079 for PPO vs. CPO
# U=25.0, p=0.0079 for PPO vs. PID-Lag
# U=25.0, p=0.0079 for PPO vs. CPPO-PID
# U=12.0, p=1.0000 for PPO vs. PPO+EWC
# U=25.0, p=0.0079 for PPO vs. Exp. Replay
# U=25.0, p=0.0079 for PPO vs. Safe EWC
# U=10.0, p=0.6905 for CPO vs. PID-Lag
# U=3.0, p=0.0556 for CPO vs. CPPO-PID
# U=5.0, p=0.1508 for CPO vs. PPO+EWC
# U=20.0, p=0.1508 for CPO vs. Exp. Replay
# U=15.0, p=0.6905 for CPO vs. Safe EWC
# U=7.0, p=0.3095 for PID-Lag vs. CPPO-PID
# U=4.0, p=0.0952 for PID-Lag vs. PPO+EWC
# U=20.0, p=0.1508 for PID-Lag vs. Exp. Replay
# U=17.0, p=0.4206 for PID-Lag vs. Safe EWC
# U=5.0, p=0.1508 for CPPO-PID vs. PPO+EWC
# U=20.0, p=0.1508 for CPPO-PID vs. Exp. Replay
# U=21.0, p=0.0952 for CPPO-PID vs. Safe EWC
# U=24.0, p=0.0159 for PPO+EWC vs. Exp. Replay
# U=23.0, p=0.0317 for PPO+EWC vs. Safe EWC
# U=7.0, p=0.3095 for Exp. Replay vs. Safe EWC
